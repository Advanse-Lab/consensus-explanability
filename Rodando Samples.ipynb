# %%
# !pip install --quiet -r requirements.txt

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for statistical data visualization
# %matplotlib inline
from ExKMC.Tree import Tree
from IPython.display import Image

np.random.seed(1)
import sys

import sklearn
import sklearn.ensemble
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

import shap
import joblib as jbl

import lime
import lime.lime_tabular

from anchor import utils
from anchor import anchor_tabular

# %%
data = pd.read_csv("21092023_Dataset_40k.csv")
data=data.set_index("id_")

# %%
# Separação de treino e teste
X = data.drop(['y'], axis=1)
y = data['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

forest = RandomForestClassifier(random_state=0)
forest.fit(X_train, y_train)

feature_names=list(X_train.columns)

# %%
# Importando shap
try:
    with open("./" + 'shap_explainer', 'rb') as f:
        explainer_shap = jbl.load(f)
except:
    explainer_shap = shap.TreeExplainer(forest)
    with open("./" + 'shap_explainer', 'wb') as f:
        jbl.dump(explainer_shap, f)

# %%
# LIME has one explainer for all the models
explainer_lime = lime.lime_tabular.LimeTabularExplainer(X_train.values, feature_names=X_train.columns.values.tolist(), class_names=[0, 1], verbose=True, mode='classification',  discretize_continuous=True)

# %%
explainer_anchors = anchor_tabular.AnchorTabularExplainer(
    [0, 1],
    X_train.columns.values.tolist(),
    X_train.values,
    {})

# %%
amostras = pd.read_csv("Amostra-Dataset.csv")

indices_positivos = amostras['id_'].to_list()
print(indices_positivos)

amostras=amostras.set_index("id_")
amostras
# Out:
# [60621, 63330, 84054, 99548, 42623, 62913, 64822, 833560, 45080, 45343]
#         methodAnonymousClassesQty  methodAssignmentsQty  methodCbo
# id_
# 60621                           0                     9          1  \
# 63330                           1                     4         13
# 84054                           0                    13         10
# 99548                           1                    12         10
# 42623                           0                     0          9
# 62913                           1                    13          9
# 64822                           0                    14         22
# 833560                          1                    19         14
# 45080                           0                    22         12
# 45343                           0                     4         12
#
#         methodComparisonsQty  methodLambdasQty  methodLoc  methodLoopQty
# id_
# 60621                      0                 0         77              0  \
# 63330                      0                 0         41              3
# 84054                      4                 0         44              0
# 99548                      0                 0         40              0
# 42623                      0                 0         44              0
# 62913                      2                 0         41              0
# 64822                      1                 0         18              0
# 833560                     3                 0         48              0
# 45080                      0                 2         50              0
# 45343                      0                 0         22              0
#
#         methodMathOperationsQty  methodMaxNestedBlocks  methodNumbersQty  ...
# id_                                                                       ...
# 60621                        64                      1                59  ...  \
# 63330                         0                      1                 0  ...
# 84054                         0                      1                 0  ...
# 99548                         0                      1                 0  ...
# 42623                         0                      1                 0  ...
# 62913                         0                      1                 0  ...
# 64822                         0                      1                 0  ...
# 833560                        4                      1                 6  ...
# 45080                         0                      1                 2  ...
# 45343                         0                      1                 1  ...
#
#         methodReturnQty  methodRfc  methodStringLiteralsQty
# id_
# 60621                 0         32                        0  \
# 63330                 1         12                        6
# 84054                 5         17                        0
# 99548                 1         17                        0
# 42623                14         11                        2
# 62913                 0         17                        3
# 64822                 1          4                        0
# 833560                3         21                        3
# 45080                 0         26                        0
# 45343                 2         23                        0
#
#         methodSubClassesQty  methodTryCatchQty  methodUniqueWordsQty
# id_
# 60621                     0                  0                    22  \
# 63330                     0                  0                    36
# 84054                     0                  0                    32
# 99548                     0                  1                    52
# 42623                     0                  0                    35
# 62913                     0                  0                    48
# 64822                     0                  0                    52
# 833560                    0                  0                    56
# 45080                     0                  0                    48
# 45343                     0                  0                    24
#
#         methodVariablesQty  methodWmc  bugFixCount  refactoringsInvolved
# id_
# 60621                    8          4            4                     4
# 63330                    3          6            3                    11
# 84054                   10          9           13                    42
# 99548                    8          4           51                    30
# 42623                    0         14            7                    13
# 62913                    2          7          172                    67
# 64822                   14          1            0                     8
# 833560                  17          6           13                    24
# 45080                   12          4            2                     8
# 45343                    4          4           60                    25
#
# [10 rows x 22 columns]

# %%
def export_shap_exp(feature_names, shap_values):
    shap_values_refatora = shap_values[1]
    shap_output = dict()
    features_exp = []
    for i in range(0, len(feature_names)):
        f = dict()
        f['nome_feature'] = feature_names[i]
        f['peso_feature'] = shap_values_refatora[i]
        f['feature_ranges'] = None
        features_exp.append(f)
    shap_output['features'] = features_exp
    return shap_output

def export_lime_exp(feature_names, exp_lime):
    lime_output = dict()
    lime_output['intercept'] = exp_lime.intercept[1]
    lime_output['local_prediction'] = exp_lime.local_pred[0]
    lime_features = exp_lime.as_list()
    features_exp = []
    for value in lime_features:
        f = dict()
        any((feature_name := substring) in value[0] for substring in feature_names)
        f['nome_feature'] = feature_name
        f['peso_feature'] = value[1]
        f['feature_ranges'] = value[0]
        features_exp.append(f)
    lime_output['features'] = features_exp
    return lime_output

def export_anchors_exp(feature_names, anchors_exp):
    anchors_output = dict()
    anchors_output['precision'] = anchors_exp.precision()
    anchors_output['coverage'] = anchors_exp.coverage()
    
    features_exp = []
    for name in anchors_exp.names():
        f = dict()
        any((feature_name := substring) in str(name) for substring in feature_names)
        f['nome_feature'] = feature_name
        f['peso_feature'] = None
        f['feature_ranges'] = name
        features_exp.append(f)
    anchors_output['features'] = features_exp
    return anchors_output

# %%
def roda_exporta_explicadores(amostras, i):
    feature_names = list(amostras.columns)
    
    #SHAP
    row = amostras.iloc[i]
    to_predict = row.values.reshape(1, -1)
    forest_predict = sum(forest.predict_proba(to_predict))
    shap_values = explainer_shap.shap_values(row)
    shap_output = export_shap_exp(feature_names, shap_values)

    #LIME
    exp_lime = explainer_lime.explain_instance(amostras.values[i], forest.predict_proba, num_features=8)
    lime_output = export_lime_exp(feature_names, exp_lime)

    #ANCHORS
    exp_anchors = explainer_anchors.explain_instance(amostras.values[i], forest.predict, threshold=0.95)
    anchors_output = export_anchors_exp(feature_names, exp_anchors)
    return [shap_output, lime_output, anchors_output]

# %%
import json

def exporta_json_explicacoes(amostras, indices):
    explicacoes = dict()
    for i in range(0, len(amostras)):
        json_output = {}
        # gives values of random forest predictions
        predict = forest.predict_proba(amostras.iloc[[i]])[0]
        json_output['forest_predict'] = {'nao refatorar': predict[0], 'refatorar': predict[1]}
        # calls funtions that run and export shap, lime and anchors explanations
        json_output['shap'], json_output['lime'], json_output['anchors'] = roda_exporta_explicadores(amostras, i)
        # puts explanations in each indice
        explicacoes[indices[i]] = json_output
    return explicacoes

json_output_exp = exporta_json_explicacoes(amostras, indices_positivos)
# Out:
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# Intercept 0.36697079934708743
# Prediction_local [0.7620009]
# Right: 0.72
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# Intercept 0.4750223184078203
# Prediction_local [0.73752678]
# Right: 0.81
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# Intercept 0.4367949495552883
# Prediction_local [0.68666112]
# Right: 0.97
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# Intercept 0.5019894809389651
# Prediction_local [0.5031356]
# Right: 0.51
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# ...
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names

# %%
#pretty print for json
print(json.dumps(json_output_exp, indent=4))

with open("explicacoes_samples.json", "w") as outfile:
    json.dump(json_output_exp, outfile)
# Out:
# {
#     "60621": {
#         "forest_predict": {
#             "nao refatorar": 0.28,
#             "refatorar": 0.72
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0003608535201939072,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.026450348447629835,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": -0.014071973055749535,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": -0.0015157261237991099,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 9.084629673378033e-05,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.058553218067354224,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": -0.0020882532157582056,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": -0.038113193084016124,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.010156880433909029,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": -0.04591613496242705,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.012766059664577023,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": -0.021259800281715962,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": -0.0011985909653885974,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05268806497404086,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": -0.0028220200985546447,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 4.4078172909521527e-05,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.001827909114364533,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.028932669857590992,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.04076783238029673,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.011116257148607969,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.08669926474690005,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.01671722985781716,
#                     "feature_ranges": null
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.36697079934708743,
#             "local_prediction": 0.7620008952621606,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.14740200375125803,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00"
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 0.050715205717676445,
#                     "feature_ranges": "methodSubClassesQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.04767163968127059,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04732563112336593,
#                     "feature_ranges": "methodLoc > 25.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.034328844466067425,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00"
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.028843265586839157,
#                     "feature_ranges": "methodAssignmentsQty > 5.00"
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.02262941292568171,
#                     "feature_ranges": "methodVariablesQty > 3.00"
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.016114092662914015,
#                     "feature_ranges": "methodStringLiteralsQty <= 0.00"
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9750692520775623,
#             "coverage": 0.034,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 4.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00"
#                 }
#             ]
#         }
#     },
#     "63330": {
#         "forest_predict": {
#             "nao refatorar": 0.19,
#             "refatorar": 0.81
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": -0.009380044056461607,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.014113813400851773,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": -0.0046672888414436954,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.003006743404812675,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.00047334695391865574,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.07097727154387841,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": -0.02129757719695137,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0009781818281547202,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": -0.0031240007060427005,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0024517770819787498,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.011545676016778798,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.001320897685854606,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": -0.0025550654956946503,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.04771967236981946,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": -0.014266116642276049,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 7.491428865380632e-05,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0018663813346113942,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.0627996083899755,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.015180589342788542,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.011428481808361405,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.13021479262833538,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": -0.008676234244385416,
#                     "feature_ranges": null
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.4750223184078203,
#             "local_prediction": 0.7375267757210592,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.15291568465993183,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.05452061356054177,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05244261290757452,
#                     "feature_ranges": "methodLoc > 25.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.043020920209946044,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": -0.025014444353500493,
#                     "feature_ranges": "methodSubClassesQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.01986229460778667,
#                     "feature_ranges": "methodWmc > 5.00"
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.019198772124735315,
#                     "feature_ranges": "methodLambdasQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": -0.016044452154306083,
#                     "feature_ranges": "methodStringLiteralsQty > 2.00"
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9624624624624625,
#             "coverage": 0.0309,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 4.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00"
#                 }
#             ]
#         }
#     },
#     "84054": {
#         "forest_predict": {
#             "nao refatorar": 0.03,
#             "refatorar": 0.97
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0008450124229482799,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.052016565430834535,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.01323758524458843,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.010818958052815056,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.0002970828696750368,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.08169952207141529,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.005691258159848672,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0036308162217063016,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.008729147639901638,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.010113086954582563,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.0037197854784388547,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0017564105935530478,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": -0.0013064553307055114,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.09323812651754765,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.004112374348361524,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 3.0586680700167566e-05,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0034852486341215437,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.06467839113109065,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.05148640570651179,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.02571147744757186,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.01270010429436888,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.023494330325642125,
#                     "feature_ranges": null
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.4367949495552883,
#             "local_prediction": 0.68666111614364,
#             "features": [
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05545262424099319,
#                     "feature_ranges": "methodLoc > 25.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.049282192111633746,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.044740111508866476,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00"
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.04163311733814181,
#                     "feature_ranges": "refactoringsInvolved > 13.00"
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.02714330945424726,
#                     "feature_ranges": "methodAssignmentsQty > 5.00"
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.025155114724466014,
#                     "feature_ranges": "methodVariablesQty > 3.00"
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.02299389616263313,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": -0.016534198952629902,
#                     "feature_ranges": "methodCbo > 5.00"
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9670152855993563,
#             "coverage": 0.0201,
#             "features": [
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 18.00"
#                 }
#             ]
#         }
#     },
#     "99548": {
#         "forest_predict": {
#             "nao refatorar": 0.49,
#             "refatorar": 0.51
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": -0.0018900394469392931,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.03081937901053193,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.004571488265823622,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": -0.005417427931577653,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.0009377760320987141,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05632241360312517,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.0012453822970158739,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.003843254451027073,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.003409350810319622,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0033611188150419833,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.0023739205365156464,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": -0.005961422673811272,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": -0.0006411808091354163,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05147922708284845,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.014684854764444527,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 3.796730653958034e-05,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": -0.005854926765492376,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.07082448762246794,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.023806360696720406,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.005221040363847994,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.2632474139284218,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.022135762856746746,
#                     "feature_ranges": null
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5019894809389651,
#             "local_prediction": 0.5031355984045903,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.26276798090336323,
#                     "feature_ranges": "bugFixCount > 18.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.056341654618297515,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.052392731049071335,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.0510248577397949,
#                     "feature_ranges": "methodLoc > 25.00"
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.04261278818064292,
#                     "feature_ranges": "refactoringsInvolved > 13.00"
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.027612476380322826,
#                     "feature_ranges": "methodAssignmentsQty > 5.00"
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.022999592355085773,
#                     "feature_ranges": "methodVariablesQty > 3.00"
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 0.010929998045773168,
#                     "feature_ranges": "methodSubClassesQty <= 0.00"
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9506437768240343,
#             "coverage": 0.0008,
#             "features": [
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks > 0.00"
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLambdasQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLoc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00"
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodParametersQty <= 2.00"
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": null,
#                     "feature_ranges": "methodCbo > 2.00"
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodComparisonsQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodStringLiteralsQty <= 0.00"
#                 }
#             ]
#         }
#     },
#     "42623": {
#         "forest_predict": {
#             "nao refatorar": 0.1,
#             "refatorar": 0.9
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": -0.00031006096898034266,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": -0.03014185995140853,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.006618172243035008,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.002516242300954705,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.00016728699148169378,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.09943747537281462,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.004174637288898191,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0002566526803513638,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.009847588831970124,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0063962228434345314,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.012627762278196857,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0021351196095788848,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": -0.00912699655705986,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.09286582525476964,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.0063908325198334896,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 5.2923896729520325e-05,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.001583891659593615,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.07632619693015875,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": -0.02369126479347518,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.03626241164610176,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.08418179569401699,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.02161496512452916,
#                     "feature_ranges": null
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.4696863069652361,
#             "local_prediction": 0.6049750650926828,
#             "features": [
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04889854334786181,
#                     "feature_ranges": "methodLoc > 25.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.045765492105954056,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 0.04482982559458615,
#                     "feature_ranges": "methodSubClassesQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.044619053531547666,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00"
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": -0.024569502218721017,
#                     "feature_ranges": "methodAssignmentsQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.02388563811062787,
#                     "feature_ranges": "methodLambdasQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": -0.01787050799318275,
#                     "feature_ranges": "methodVariablesQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.017501491870028668,
#                     "feature_ranges": "methodWmc > 5.00"
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9771309771309772,
#             "coverage": 0.0086,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 18.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLoc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00"
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks <= 1.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00"
#                 }
#             ]
#         }
#     },
#     "62913": {
#         "forest_predict": {
#             "nao refatorar": 0.51,
#             "refatorar": 0.49
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0026164686228513467,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.03493254310843103,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.007677328858526726,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.00526291791656694,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.00041573326313601563,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05196349764413738,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.00314811430854426,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.00237935679397022,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.004284857368149526,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0015016715745150091,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.008345431115244654,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.018377924610596556,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": -0.004175868490878303,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.06741885767215788,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.009010479897717283,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 3.261298519600668e-05,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0015955898233920268,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.045098165489465596,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.013394203873891907,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": -0.0010102335550829199,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.28849902211051665,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.007246656651782406,
#                     "feature_ranges": null
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5547940102138454,
#             "local_prediction": 0.466436115532828,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.26343872373075045,
#                     "feature_ranges": "bugFixCount > 18.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.052804792846263576,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.05123922535644915,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04577998734726904,
#                     "feature_ranges": "methodLoc > 25.00"
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.043065275981376175,
#                     "feature_ranges": "refactoringsInvolved > 13.00"
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.026304835103215858,
#                     "feature_ranges": "methodAssignmentsQty > 5.00"
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.02623911185611163,
#                     "feature_ranges": "methodLambdasQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": -0.017874175728729194,
#                     "feature_ranges": "methodStringLiteralsQty > 2.00"
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9581950895819509,
#             "coverage": 0.1516,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount > 18.00"
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks <= 1.00"
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodVariablesQty <= 3.00"
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMathOperationsQty <= 0.00"
#                 }
#             ]
#         }
#     },
#     "64822": {
#         "forest_predict": {
#             "nao refatorar": 0.2,
#             "refatorar": 0.8
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": -0.0006924328835148324,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.026642940955974984,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": -0.02715651932617241,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.012211409116779528,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.0008842582097205729,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04143820873113514,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.00348371874348488,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0005561720569322364,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.010277156718715432,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0058037258019801715,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.0018955708292567885,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.00341093664943417,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": -0.0009863560095447485,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": -0.00029770608594788516,
# ...
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.002737573170635661,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0015203065216339835,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.006016563459752752,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.004352155179954369,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.01143208435388627,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0019929277746495314,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": 0.0016627253960580057,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.07390051978880398,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.0017242576070072863,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 6.957368098098687e-05,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0008123089238036233,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.06369349796635064,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.045786104773019316,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.010239989739574386,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.11294127770177226,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.016973560058933967,
#                     "feature_ranges": null
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.3763627684303318,
#             "local_prediction": 0.7781123969964343,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.14675886769276292,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05019871041051883,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.047274500900550895,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04558212567559358,
#                     "feature_ranges": "methodLoc > 25.00"
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 0.02984027604150122,
#                     "feature_ranges": "methodSubClassesQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.029745240796010233,
#                     "feature_ranges": "methodAssignmentsQty > 5.00"
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.028544698322224945,
#                     "feature_ranges": "methodVariablesQty > 3.00"
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.023805208726939857,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00"
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9535911602209944,
#             "coverage": 0.0704,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 4.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLoc > 10.00"
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00"
#                 }
#             ]
#         }
#     },
#     "45343": {
#         "forest_predict": {
#             "nao refatorar": 0.15,
#             "refatorar": 0.85
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0008294048742944157,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.04584139612623714,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.02694551940038682,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.00024286798679042497,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.00020264228134674828,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.06646625363235044,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.0074799922330103606,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.00783002436698856,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.016866295446847875,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.009367451168481396,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": -0.0009454341703474434,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0012463355860067966,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": 0.015358447970906441,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.14332161169559038,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.02418472647899579,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 4.209015663368147e-05,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0047115777457229354,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.06654824552903807,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.04552689635125442,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.025504558557528836,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.2041275691362493,
#                     "feature_ranges": null
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.047147771176400614,
#                     "feature_ranges": null
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5611195780742984,
#             "local_prediction": 0.439434392168075,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.2611660247825484,
#                     "feature_ranges": "bugFixCount > 18.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.053250017758029136,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.041029785042380425,
#                     "feature_ranges": "refactoringsInvolved > 13.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.03427155971082934,
#                     "feature_ranges": "10.00 < methodLoc <= 25.00"
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.02587608915875851,
#                     "feature_ranges": "methodVariablesQty > 3.00"
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": -0.023643685507308398,
#                     "feature_ranges": "methodSubClassesQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.023066737375105232,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00"
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": -0.014369664661469148,
#                     "feature_ranges": "methodCbo > 5.00"
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9206161137440758,
#             "coverage": 0.0,
#             "features": [
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00"
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodVariablesQty > 3.00"
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 13.00"
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLoc > 10.00"
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodAssignmentsQty > 1.00"
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodWmc > 2.00"
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks > 0.00"
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": null,
#                     "feature_ranges": "methodCbo > 5.00"
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMathOperationsQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLambdasQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": null,
#                     "feature_ranges": "0.00 < methodNumbersQty <= 1.00"
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodComparisonsQty <= 1.00"
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodAnonymousClassesQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodStringLiteralsQty <= 2.00"
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLoopQty <= 0.00"
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodReturnQty > 1.00"
#                 }
#             ]
#         }
#     }
# }

# %%
def instancia_explicabilidade_local(i, amostras, shap_exps, lime_exps):
    # mostra row
    print("Instância nº: ", indices_positivos[i])
    print(amostras.iloc[i])
    print("Predição do Random Forest: ", forest.predict_proba(amostras.iloc[[i]]))
    
    #SHAP
    print("SHAP")
    row = amostras.iloc[i]
    to_predict = row.values.reshape(1, -1)
    forest_predict = sum(forest.predict_proba(to_predict))
    shap_values = explainer_shap.shap_values(row)
    shap.initjs()
    display(shap.force_plot(explainer_shap.expected_value[1], shap_values[1], row))
    shap_output = export_shap_exp(i, forest_predict[1], explainer_shap.expected_value, shap_values)
    #shap_exps.join(shap_output)
    shap_result = pd.concat([shap_exps, shap_output], ignore_index=True)

    #LIME
    print("LIME")
    exp_lime = explainer_lime.explain_instance(amostras.values[i], forest.predict_proba, num_features=8)
    exp_lime.show_in_notebook(show_table=True)
    lime_output = export_lime_exp(i, forest_predict[1], exp_lime.intercept[1], exp_lime.local_pred, exp_lime.as_list())
    #lime_exps.join(lime_output)
    lime_result = pd.concat([lime_exps, lime_output], ignore_index=True)

    #ANCHORS
    print("ANCHORS")
    exp_anchors = explainer_anchors.explain_instance(amostras.values[i], forest.predict, threshold=0.95)
    print('Anchor: %s' % (' AND '.join(exp_anchors.names())))
    print('Precision: %.2f' % exp_anchors.precision())
    print('Coverage: %.2f' % exp_anchors.coverage())
    exp_anchors.show_in_notebook()

    print("-----------------------------------------------------------------------------------------------")

    return (shap_result, lime_result)

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
shap_output = pd.DataFrame()
lime_output = pd.DataFrame()
for i in range(0,10):
    (shap_output, lime_output) = instancia_explicabilidade_local(i, amostras, shap_output, lime_output)

# %%
shap_output.to_csv('shap_explanations.csv')
lime_output.to_csv('lime_explanations.csv')

# %%
shap_output

# %%
display(lime_output)

# %%
shap_output = shap_output.drop(['forest prediction to refactorating', 'base value', 'row'], axis=1)

lime_output = lime_output.drop(['forest prediction to refactorating', 'intercept', 'local prediction', 'row'], axis=1)
lime_output = lime_output.loc[:, ~lime_output.columns.str.endswith('description')]
lime_output = lime_output.fillna(0)
lime_output = lime_output.apply(pd.to_numeric)

# %%
def display_top_5_features(output, i):
    top5 = output.iloc[i].nlargest(5).to_frame().T
    display(top5)

for f in range(0,10):
    display_top_5_features(shap_output, f)
    display_top_5_features(lime_output, f)
