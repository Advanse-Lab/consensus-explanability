# %% [markdown]
# # Primeiros Passos

# %% [markdown]
# ## Importação de bibliotecas

# %%
#!pip install --quiet -r requirements.txt

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for statistical data visualization
# %matplotlib inline
from ExKMC.Tree import Tree
from IPython.display import Image

np.random.seed(1)
import sys

import sklearn
import sklearn.ensemble
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

import shap
import joblib as jbl

import lime
import lime.lime_tabular

from anchor import utils
from anchor import anchor_tabular

import json
import warnings

# %% [markdown]
# ## Importando dataset e rodando Random Forest

# %%
data = pd.read_csv("21092023_Dataset_40k.csv")
data=data.set_index("id_")

# %%
amostras = pd.read_csv("Amostra-Dataset.csv")

indices_positivos = amostras['id_'].to_list()
print(indices_positivos)

amostras=amostras.set_index("id_")
amostras
# Out:
# [60621, 63330, 84054, 99548, 42623, 62913, 64822, 833560, 45080, 45343]
#         methodAnonymousClassesQty  methodAssignmentsQty  methodCbo  \
# id_
# 60621                           0                     9          1
# 63330                           1                     4         13
# 84054                           0                    13         10
# 99548                           1                    12         10
# 42623                           0                     0          9
# 62913                           1                    13          9
# 64822                           0                    14         22
# 833560                          1                    19         14
# 45080                           0                    22         12
# 45343                           0                     4         12
#
#         methodComparisonsQty  methodLambdasQty  methodLoc  methodLoopQty  \
# id_
# 60621                      0                 0         77              0
# 63330                      0                 0         41              3
# 84054                      4                 0         44              0
# 99548                      0                 0         40              0
# 42623                      0                 0         44              0
# 62913                      2                 0         41              0
# 64822                      1                 0         18              0
# 833560                     3                 0         48              0
# 45080                      0                 2         50              0
# 45343                      0                 0         22              0
#
#         methodMathOperationsQty  methodMaxNestedBlocks  methodNumbersQty  ...  \
# id_                                                                       ...
# 60621                        64                      1                59  ...
# 63330                         0                      1                 0  ...
# 84054                         0                      1                 0  ...
# 99548                         0                      1                 0  ...
# 42623                         0                      1                 0  ...
# 62913                         0                      1                 0  ...
# 64822                         0                      1                 0  ...
# 833560                        4                      1                 6  ...
# 45080                         0                      1                 2  ...
# 45343                         0                      1                 1  ...
#
#         methodReturnQty  methodRfc  methodStringLiteralsQty  \
# id_
# 60621                 0         32                        0
# 63330                 1         12                        6
# 84054                 5         17                        0
# 99548                 1         17                        0
# 42623                14         11                        2
# 62913                 0         17                        3
# 64822                 1          4                        0
# 833560                3         21                        3
# 45080                 0         26                        0
# 45343                 2         23                        0
#
#         methodSubClassesQty  methodTryCatchQty  methodUniqueWordsQty  \
# id_
# 60621                     0                  0                    22
# 63330                     0                  0                    36
# 84054                     0                  0                    32
# 99548                     0                  1                    52
# 42623                     0                  0                    35
# 62913                     0                  0                    48
# 64822                     0                  0                    52
# 833560                    0                  0                    56
# 45080                     0                  0                    48
# 45343                     0                  0                    24
#
#         methodVariablesQty  methodWmc  bugFixCount  refactoringsInvolved
# id_
# 60621                    8          4            4                     4
# 63330                    3          6            3                    11
# 84054                   10          9           13                    42
# 99548                    8          4           51                    30
# 42623                    0         14            7                    13
# 62913                    2          7          172                    67
# 64822                   14          1            0                     8
# 833560                  17          6           13                    24
# 45080                   12          4            2                     8
# 45343                    4          4           60                    25
#
# [10 rows x 22 columns]

# %%
# Separação de treino e teste
X = data.drop(['y'], axis=1)
y = data['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

forest = RandomForestClassifier(random_state=0)
forest.fit(X_train, y_train)

feature_names=list(X_train.columns)

# %% [markdown]
# ## Inicializando expicadores

# %%
# Importando shap
try:
    with open("./" + 'shap_explainer', 'rb') as f:
        explainer_shap = jbl.load(f)
except:
    explainer_shap = shap.TreeExplainer(forest)
    with open("./" + 'shap_explainer', 'wb') as f:
        jbl.dump(explainer_shap, f)

# %%
# LIME has one explainer for all the models
explainer_lime = lime.lime_tabular.LimeTabularExplainer(X_train.values, feature_names=X_train.columns.values.tolist(), class_names=[0, 1], verbose=True, mode='classification',  discretize_continuous=True)

# %%
explainer_anchors = anchor_tabular.AnchorTabularExplainer(
    [0, 1],
    X_train.columns.values.tolist(),
    X_train.values,
    {})

# %% [markdown]
# # Rodando instâncias e mostrando gráficos

# %%
# function to show explicability methods graphs
def instancia_explicabilidade_local(i, amostras):
    # mostra row
    print("Instância nº: ", indices_positivos[i])
    print(amostras.iloc[i])
    print("Predição do Random Forest: ", forest.predict_proba(amostras.iloc[[i]]))
    
    #SHAP
    print("SHAP")
    row = amostras.iloc[i]
    to_predict = row.values.reshape(1, -1)
    forest_predict = sum(forest.predict_proba(to_predict))
    shap_values = explainer_shap.shap_values(row)
    shap.initjs()
    display(shap.force_plot(explainer_shap.expected_value[1], shap_values[1], row))
    # shap_output = export_shap_exp(i, forest_predict[1], explainer_shap.expected_value, shap_values)
    # shap_exps.join(shap_output)
    # shap_result = pd.concat([shap_exps, shap_output], ignore_index=True)

    #LIME
    print("LIME")
    exp_lime = explainer_lime.explain_instance(amostras.values[i], forest.predict_proba, num_features=8)
    exp_lime.show_in_notebook(show_table=True)
    # lime_output = export_lime_exp(i, forest_predict[1], exp_lime.intercept[1], exp_lime.local_pred, exp_lime.as_list())
    # lime_exps.join(lime_output)
    # lime_result = pd.concat([lime_exps, lime_output], ignore_index=True)

    #ANCHORS
    print("ANCHORS")
    exp_anchors = explainer_anchors.explain_instance(amostras.values[i], forest.predict, threshold=0.95)
    print('Anchor: %s' % (' AND '.join(exp_anchors.names())))
    print('Precision: %.2f' % exp_anchors.precision())
    print('Coverage: %.2f' % exp_anchors.coverage())
    exp_anchors.show_in_notebook()

    print("-----------------------------------------------------------------------------------------------")

# %% [markdown]
# # Exportando as explicações

# %% [markdown]
# ## Formato json

# %% [markdown]
# ### Exporta features e dados gerais de cada explicador

# %%
# function to help sorting features
def compare_shap_feature_weights(feature_value):
    # highest weights first
    return -feature_value['peso_feature']

# export shap features' explanations
def export_shap_exp(feature_names, shap_values):
    # get shap values to refactor instance
    shap_values_refatora = shap_values[1]
    shap_output = dict()
    features_exp = []
    for i in range(0, len(feature_names)):
        # shap_values has positive values (to refactor) and negative ones (not to refactor)
        if shap_values_refatora[i] > 0:
            f = dict()
            f['nome_feature'] = feature_names[i]
            f['peso_feature'] = shap_values_refatora[i]
            f['feature_ranges'] = None
            features_exp.append(f)
    # sort features by feature weight
    sorted_features_exp = sorted(features_exp, key=compare_shap_feature_weights)
    #insere prioridade após ser ordenado
    prioridade = 1
    for f in sorted_features_exp:
        f['prioridade'] = prioridade
        prioridade = prioridade + 1
    shap_output['features'] = sorted_features_exp
    return shap_output

# export lime features' explanations
def export_lime_exp(feature_names, exp_lime):
    lime_output = dict()
    # general instance indices
    lime_output['intercept'] = exp_lime.intercept[1]
    lime_output['local_prediction'] = exp_lime.local_pred[0]
    lime_features = exp_lime.as_list()
    # features' values
    features_exp = []
    prioridade = 1
    for value in lime_features:
        f = dict()
        # extract feature name from feature ranges string
        any((feature_name := substring) in value[0] for substring in feature_names)
        f['nome_feature'] = feature_name
        f['peso_feature'] = value[1]
        f['feature_ranges'] = value[0]
        f['prioridade'] = prioridade #ordem de prioridade da feature
        features_exp.append(f)
        prioridade = prioridade + 1
    lime_output['features'] = features_exp
    return lime_output

# export anchors features' explanations
def export_anchors_exp(feature_names, anchors_exp):
    anchors_output = dict()
    # general instance indices
    anchors_output['precision'] = anchors_exp.precision()
    anchors_output['coverage'] = anchors_exp.coverage()
    # features' values
    features_exp = []
    prioridade = 1
    for name in anchors_exp.names():
        f = dict()
        # extract feature name from anchors' names string
        any((feature_name := substring) in str(name) for substring in feature_names)
        f['nome_feature'] = feature_name
        f['peso_feature'] = None
        f['feature_ranges'] = name
        f['prioridade'] = prioridade #ordem de prioridade da feature
        features_exp.append(f)
        prioridade = prioridade + 1
    anchors_output['features'] = features_exp
    return anchors_output

# %% [markdown]
# ### Roda os explicadores para um conjunto de amostrar e exporta cada um

# %%
def roda_exporta_explicadores(amostras, i):
    feature_names = list(amostras.columns)
    
    #SHAP
    row = amostras.iloc[i]
    to_predict = row.values.reshape(1, -1)
    forest_predict = sum(forest.predict_proba(to_predict))
    shap_values = explainer_shap.shap_values(row)
    shap_output = export_shap_exp(feature_names, shap_values)

    #LIME
    exp_lime = explainer_lime.explain_instance(amostras.values[i], forest.predict_proba, num_features=8)
    lime_output = export_lime_exp(feature_names, exp_lime)

    #ANCHORS
    exp_anchors = explainer_anchors.explain_instance(amostras.values[i], forest.predict, threshold=0.95)
    anchors_output = export_anchors_exp(feature_names, exp_anchors)
    return [shap_output, lime_output, anchors_output]

# %% [markdown]
# ### Junta as explicações em um json com dados da instância

# %%
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
def exporta_json_explicacoes(amostras, indices):
    explicacoes = dict()
    for i in range(0, len(amostras)):
        json_output = {}
        # gives values of random forest predictions
        predict = forest.predict_proba(amostras.iloc[[i]])[0]
        json_output['forest_predict'] = {'nao refatorar': predict[0], 'refatorar': predict[1]}
        # calls funtions that run and export shap, lime and anchors explanations
        json_output['shap'], json_output['lime'], json_output['anchors'] = roda_exporta_explicadores(amostras, i)
        # puts explanations in each indice
        explicacoes[indices[i]] = json_output
        #export explicacoes to json file
        with open("explicacoes_samples.json", "w") as outfile:
            json.dump(json_output, outfile)
    return explicacoes

json_output_exp = exporta_json_explicacoes(amostras, indices_positivos)
#pretty print for json
print(json.dumps(json_output_exp, indent=4))
# Out:
# Intercept 0.4349535690065091
# Prediction_local [0.77731915]
# Right: 0.72
# Intercept 0.3607798134139092
# Prediction_local [0.74519327]
# Right: 0.81
# Intercept 0.45712981731856434
# Prediction_local [0.70629246]
# Right: 0.97
# Intercept 0.5311779229377486
# Prediction_local [0.51066776]
# Right: 0.51
# Intercept 0.5498197315722846
# Prediction_local [0.58631919]
# Right: 0.9
# Intercept 0.5326000693851246
# Prediction_local [0.44820913]
# Right: 0.49
# Intercept 0.42847172418630164
# Prediction_local [0.68704775]
# Right: 0.8
# Intercept 0.48427608166607006
# Prediction_local [0.68380042]
# Right: 0.84
# Intercept 0.40773193467482605
# Prediction_local [0.7648461]
# Right: 0.98
# Intercept 0.5364074963320494
# Prediction_local [0.4575002]
# Right: 0.85
# {
#     "60621": {
#         "forest_predict": {
#             "nao refatorar": 0.28,
#             "refatorar": 0.72
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.08669926474690005,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.058553218067354224,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05268806497404086,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.04076783238029673,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.028932669857590992,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.026450348447629835,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.01671722985781716,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.012766059664577023,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.011116257148607969,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.010156880433909029,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.001827909114364533,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0003608535201939072,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 9.084629673378033e-05,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 4.4078172909521527e-05,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.4349535690065091,
#             "local_prediction": 0.7773191454422511,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.1367958122599585,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05520834638214641,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.053828724236807686,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.039378870041254316,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.027762194358496747,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.02409377329320792,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.019359931506358136,
#                     "feature_ranges": "methodParametersQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.014062075642487707,
#                     "feature_ranges": "methodLambdasQty <= 0.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9708029197080292,
#             "coverage": 0.0348,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "prioridade": 3
#                 }
#             ]
#         }
#     },
#     "63330": {
#         "forest_predict": {
#             "nao refatorar": 0.19,
#             "refatorar": 0.81
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.13021479262833538,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.07097727154387841,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.0627996083899755,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.04771967236981946,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.015180589342788542,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.014113813400851773,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.011545676016778798,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.011428481808361405,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.003006743404812675,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0024517770819787498,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0018663813346113942,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.001320897685854606,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0009781818281547202,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.00047334695391865574,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 7.491428865380632e-05,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.3607798134139092,
#             "local_prediction": 0.7451932658708532,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.14718916430725937,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.060653022181763334,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 0.05585164050870991,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05125915426907109,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.04755277224929207,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.022759488264913235,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": -0.018917415629470028,
#                     "feature_ranges": "methodStringLiteralsQty > 2.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.01806562630540506,
#                     "feature_ranges": "1.00 < methodAssignmentsQty <= 5.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9635761589403974,
#             "coverage": 0.0345,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "prioridade": 3
#                 }
#             ]
#         }
#     },
#     "84054": {
#         "forest_predict": {
#             "nao refatorar": 0.03,
#             "refatorar": 0.97
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.09323812651754765,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.08169952207141529,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.06467839113109065,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.052016565430834535,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.05148640570651179,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.02571147744757186,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.023494330325642125,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.01323758524458843,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.01270010429436888,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.010818958052815056,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.010113086954582563,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.008729147639901638,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.005691258159848672,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.004112374348361524,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.0037197854784388547,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0036308162217063016,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0034852486341215437,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0017564105935530478,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0008450124229482799,
#                     "feature_ranges": null,
#                     "prioridade": 19
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.0002970828696750368,
#                     "feature_ranges": null,
#                     "prioridade": 20
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 3.0586680700167566e-05,
#                     "feature_ranges": null,
#                     "prioridade": 21
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.45712981731856434,
#             "local_prediction": 0.7062924642077191,
#             "features": [
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05571868689699968,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05140450116445657,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.04473234192018523,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.04065260664252824,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.03656703168277713,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": -0.02522049183775034,
#                     "feature_ranges": "methodAnonymousClassesQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.023652212431340133,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.021655757988618143,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9637479085331846,
#             "coverage": 0.0191,
#             "features": [
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 18.00",
#                     "prioridade": 3
#                 }
#             ]
#         }
#     },
#     "99548": {
#         "forest_predict": {
#             "nao refatorar": 0.49,
#             "refatorar": 0.51
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.07082448762246794,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05632241360312517,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05147922708284845,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.03081937901053193,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.023806360696720406,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.022135762856746746,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.014684854764444527,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.005221040363847994,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.004571488265823622,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.003843254451027073,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.003409350810319622,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0033611188150419833,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.0023739205365156464,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.0012453822970158739,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 3.796730653958034e-05,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5311779229377486,
#             "local_prediction": 0.5106677607425103,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.2596038872564849,
#                     "feature_ranges": "bugFixCount > 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.057348573452733385,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.052005294588750584,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.04974310118796689,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.03996490613989282,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.033475690931671534,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.023822431718561424,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.017266272958330036,
#                     "feature_ranges": "methodLambdasQty <= 0.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9657794676806084,
#             "coverage": 0.0018,
#             "features": [
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodParametersQty <= 2.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodAssignmentsQty > 1.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodWmc > 2.00",
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks <= 1.00",
#                     "prioridade": 10
#                 }
#             ]
#         }
#     },
#     "42623": {
#         "forest_predict": {
#             "nao refatorar": 0.1,
#             "refatorar": 0.9
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.09943747537281462,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.09286582525476964,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.08418179569401699,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.07632619693015875,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.03626241164610176,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.02161496512452916,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.012627762278196857,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.009847588831970124,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.006618172243035008,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0063962228434345314,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.0063908325198334896,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.004174637288898191,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.002516242300954705,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0021351196095788848,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.001583891659593615,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0002566526803513638,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.00016728699148169378,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 5.2923896729520325e-05,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5498197315722846,
#             "local_prediction": 0.5863191887126831,
#             "features": [
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.06039424100238056,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.05365004772844699,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": -0.05244498479106743,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04770058352549178,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": -0.03578192357764609,
#                     "feature_ranges": "methodAssignmentsQty <= 0.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": -0.031022876255275028,
#                     "feature_ranges": "methodVariablesQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": -0.026580307619070414,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.020584677127138136,
#                     "feature_ranges": "methodWmc > 5.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9601593625498008,
#             "coverage": 0.0205,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodParametersQty <= 1.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": null,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "prioridade": 5
#                 }
#             ]
#         }
#     },
#     "62913": {
#         "forest_predict": {
#             "nao refatorar": 0.51,
#             "refatorar": 0.49
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.06741885767215788,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05196349764413738,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.045098165489465596,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.03493254310843103,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.018377924610596556,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.013394203873891907,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.009010479897717283,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.008345431115244654,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.007677328858526726,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.007246656651782406,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.00526291791656694,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.004284857368149526,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.00314811430854426,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0026164686228513467,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.00237935679397022,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0015955898233920268,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0015016715745150091,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 3.261298519600668e-05,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5326000693851246,
#             "local_prediction": 0.44820912767327425,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.2557800846496146,
#                     "feature_ranges": "bugFixCount > 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.052426124936734375,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05135326209261229,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.0476362366060331,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.035786116265692156,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.02897086690380792,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": -0.024720974518525493,
#                     "feature_ranges": "methodStringLiteralsQty > 2.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": -0.020062489348590066,
#                     "feature_ranges": "methodParenthesizedExpsQty > 0.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9573770491803278,
#             "coverage": 0.1317,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount > 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks <= 1.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodVariablesQty <= 3.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodReturnQty <= 1.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodNumbersQty <= 0.00",
#                     "prioridade": 5
#                 }
#             ]
#         }
#     },
#     "64822": {
#         "forest_predict": {
#             "nao refatorar": 0.2,
#             "refatorar": 0.8
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.09076048086079677,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.0640324772455129,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.04499364746868278,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.0433356934729825,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04143820873113514,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.026642940955974984,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.012211409116779528,
#                     "feature_ranges": null,
#                     "prioridade": 7
# ...
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.004055542389255195,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.002737573170635661,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0019929277746495314,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.001797785242339524,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.0017242576070072863,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": 0.0016627253960580057,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0015203065216339835,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0008123089238036233,
#                     "feature_ranges": null,
#                     "prioridade": 19
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.00012968764880903774,
#                     "feature_ranges": null,
#                     "prioridade": 20
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 6.957368098098687e-05,
#                     "feature_ranges": null,
#                     "prioridade": 21
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.40773193467482605,
#             "local_prediction": 0.7648461020806127,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.1532614319018238,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05181390879933978,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05177623953935548,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.0473477696392469,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.03187596800884692,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.019447786086975935,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.018750339704077624,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": -0.017159276273879892,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9776876267748479,
#             "coverage": 0.0309,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "prioridade": 3
#                 }
#             ]
#         }
#     },
#     "45343": {
#         "forest_predict": {
#             "nao refatorar": 0.15,
#             "refatorar": 0.85
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.14332161169559038,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.06654824552903807,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.06646625363235044,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.047147771176400614,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.04584139612623714,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.04552689635125442,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.02694551940038682,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.025504558557528836,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.02418472647899579,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.016866295446847875,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": 0.015358447970906441,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.009367451168481396,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.00783002436698856,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.0074799922330103606,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0047115777457229354,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0012463355860067966,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0008294048742944157,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.00024286798679042497,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 4.209015663368147e-05,
#                     "feature_ranges": null,
#                     "prioridade": 19
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5364074963320494,
#             "local_prediction": 0.4575001989895098,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.25566573714540725,
#                     "feature_ranges": "bugFixCount > 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05202654323702824,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.04330142361121177,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04084024246865992,
#                     "feature_ranges": "10.00 < methodLoc <= 25.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": -0.02551829121372247,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.02265258558082305,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.022031555295782095,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.021424380823084958,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9609375,
#             "coverage": 0.0037,
#             "features": [
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodAnonymousClassesQty <= 0.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLoc > 10.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLambdasQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodAssignmentsQty > 1.00",
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 13.00",
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodWmc > 2.00",
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks > 0.00",
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodReturnQty > 0.00",
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMathOperationsQty <= 1.00",
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": null,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "prioridade": 15
#                 }
#             ]
#         }
#     }
# }

# %% [markdown]
# ## Formato csv

# %%
# shap_output = pd.DataFrame()
# lime_output = pd.DataFrame()
# for i in range(0,10):
#     (shap_output, lime_output) = instancia_explicabilidade_local(i, amostras, shap_output, lime_output)
# shap_output.to_csv('shap_explanations.csv')
# lime_output.to_csv('lime_explanations.csv')

# %% [markdown]
# # Juntando explicações

# %%
print(json.dumps(json_output_exp, indent=4))
# Out:
# {
#     "60621": {
#         "forest_predict": {
#             "nao refatorar": 0.28,
#             "refatorar": 0.72
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.08669926474690005,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.058553218067354224,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05268806497404086,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.04076783238029673,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.028932669857590992,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.026450348447629835,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.01671722985781716,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.012766059664577023,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.011116257148607969,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.010156880433909029,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.001827909114364533,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0003608535201939072,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 9.084629673378033e-05,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 4.4078172909521527e-05,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.4349535690065091,
#             "local_prediction": 0.7773191454422511,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.1367958122599585,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05520834638214641,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.053828724236807686,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.039378870041254316,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.027762194358496747,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.02409377329320792,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.019359931506358136,
#                     "feature_ranges": "methodParametersQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.014062075642487707,
#                     "feature_ranges": "methodLambdasQty <= 0.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9708029197080292,
#             "coverage": 0.0348,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "prioridade": 3
#                 }
#             ]
#         }
#     },
#     "63330": {
#         "forest_predict": {
#             "nao refatorar": 0.19,
#             "refatorar": 0.81
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.13021479262833538,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.07097727154387841,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.0627996083899755,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.04771967236981946,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.015180589342788542,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.014113813400851773,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.011545676016778798,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.011428481808361405,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.003006743404812675,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0024517770819787498,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0018663813346113942,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.001320897685854606,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0009781818281547202,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.00047334695391865574,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 7.491428865380632e-05,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.3607798134139092,
#             "local_prediction": 0.7451932658708532,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.14718916430725937,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.060653022181763334,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 0.05585164050870991,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05125915426907109,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.04755277224929207,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.022759488264913235,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": -0.018917415629470028,
#                     "feature_ranges": "methodStringLiteralsQty > 2.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.01806562630540506,
#                     "feature_ranges": "1.00 < methodAssignmentsQty <= 5.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9635761589403974,
#             "coverage": 0.0345,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "prioridade": 3
#                 }
#             ]
#         }
#     },
#     "84054": {
#         "forest_predict": {
#             "nao refatorar": 0.03,
#             "refatorar": 0.97
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.09323812651754765,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.08169952207141529,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.06467839113109065,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.052016565430834535,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.05148640570651179,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.02571147744757186,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.023494330325642125,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.01323758524458843,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.01270010429436888,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.010818958052815056,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.010113086954582563,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.008729147639901638,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.005691258159848672,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.004112374348361524,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.0037197854784388547,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0036308162217063016,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0034852486341215437,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0017564105935530478,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0008450124229482799,
#                     "feature_ranges": null,
#                     "prioridade": 19
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.0002970828696750368,
#                     "feature_ranges": null,
#                     "prioridade": 20
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 3.0586680700167566e-05,
#                     "feature_ranges": null,
#                     "prioridade": 21
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.45712981731856434,
#             "local_prediction": 0.7062924642077191,
#             "features": [
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05571868689699968,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05140450116445657,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.04473234192018523,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.04065260664252824,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.03656703168277713,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": -0.02522049183775034,
#                     "feature_ranges": "methodAnonymousClassesQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.023652212431340133,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.021655757988618143,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9637479085331846,
#             "coverage": 0.0191,
#             "features": [
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 18.00",
#                     "prioridade": 3
#                 }
#             ]
#         }
#     },
#     "99548": {
#         "forest_predict": {
#             "nao refatorar": 0.49,
#             "refatorar": 0.51
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.07082448762246794,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05632241360312517,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05147922708284845,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.03081937901053193,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.023806360696720406,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.022135762856746746,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.014684854764444527,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.005221040363847994,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.004571488265823622,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.003843254451027073,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.003409350810319622,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0033611188150419833,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.0023739205365156464,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.0012453822970158739,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 3.796730653958034e-05,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5311779229377486,
#             "local_prediction": 0.5106677607425103,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.2596038872564849,
#                     "feature_ranges": "bugFixCount > 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.057348573452733385,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.052005294588750584,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.04974310118796689,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.03996490613989282,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.033475690931671534,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.023822431718561424,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": -0.017266272958330036,
#                     "feature_ranges": "methodLambdasQty <= 0.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9657794676806084,
#             "coverage": 0.0018,
#             "features": [
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodParametersQty <= 2.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodAssignmentsQty > 1.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodWmc > 2.00",
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks <= 1.00",
#                     "prioridade": 10
#                 }
#             ]
#         }
#     },
#     "42623": {
#         "forest_predict": {
#             "nao refatorar": 0.1,
#             "refatorar": 0.9
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.09943747537281462,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.09286582525476964,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.08418179569401699,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.07632619693015875,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.03626241164610176,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.02161496512452916,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.012627762278196857,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.009847588831970124,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.006618172243035008,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0063962228434345314,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.0063908325198334896,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.004174637288898191,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.002516242300954705,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0021351196095788848,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.001583891659593615,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0002566526803513638,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.00016728699148169378,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 5.2923896729520325e-05,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5498197315722846,
#             "local_prediction": 0.5863191887126831,
#             "features": [
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.06039424100238056,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.05365004772844699,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": -0.05244498479106743,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04770058352549178,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": -0.03578192357764609,
#                     "feature_ranges": "methodAssignmentsQty <= 0.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": -0.031022876255275028,
#                     "feature_ranges": "methodVariablesQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": -0.026580307619070414,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.020584677127138136,
#                     "feature_ranges": "methodWmc > 5.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9601593625498008,
#             "coverage": 0.0205,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodParametersQty <= 1.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": null,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "prioridade": 5
#                 }
#             ]
#         }
#     },
#     "62913": {
#         "forest_predict": {
#             "nao refatorar": 0.51,
#             "refatorar": 0.49
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.06741885767215788,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05196349764413738,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.045098165489465596,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.03493254310843103,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.018377924610596556,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.013394203873891907,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.009010479897717283,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodParametersQty",
#                     "peso_feature": 0.008345431115244654,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.007677328858526726,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.007246656651782406,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.00526291791656694,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.004284857368149526,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.00314811430854426,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0026164686228513467,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.00237935679397022,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0015955898233920268,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0015016715745150091,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 3.261298519600668e-05,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5326000693851246,
#             "local_prediction": 0.44820912767327425,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.2557800846496146,
#                     "feature_ranges": "bugFixCount > 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.052426124936734375,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05135326209261229,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.0476362366060331,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.035786116265692156,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.02897086690380792,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": -0.024720974518525493,
#                     "feature_ranges": "methodStringLiteralsQty > 2.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": -0.020062489348590066,
#                     "feature_ranges": "methodParenthesizedExpsQty > 0.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9573770491803278,
#             "coverage": 0.1317,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount > 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks <= 1.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodVariablesQty <= 3.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodReturnQty <= 1.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodNumbersQty <= 0.00",
#                     "prioridade": 5
#                 }
#             ]
#         }
#     },
#     "64822": {
#         "forest_predict": {
#             "nao refatorar": 0.2,
#             "refatorar": 0.8
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.09076048086079677,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.0640324772455129,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.04499364746868278,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.0433356934729825,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04143820873113514,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.026642940955974984,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.012211409116779528,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.010277156718715432,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.0058037258019801715,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.00348371874348488,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
# ...
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": 0.004055542389255195,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.002737573170635661,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0019929277746495314,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.001797785242339524,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.0017242576070072863,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": 0.0016627253960580057,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.0015203065216339835,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0008123089238036233,
#                     "feature_ranges": null,
#                     "prioridade": 19
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.00012968764880903774,
#                     "feature_ranges": null,
#                     "prioridade": 20
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 6.957368098098687e-05,
#                     "feature_ranges": null,
#                     "prioridade": 21
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.40773193467482605,
#             "local_prediction": 0.7648461020806127,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": 0.1532614319018238,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05181390879933978,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.05177623953935548,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.0473477696392469,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.03187596800884692,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.019447786086975935,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.018750339704077624,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": -0.017159276273879892,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9776876267748479,
#             "coverage": 0.0309,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "prioridade": 3
#                 }
#             ]
#         }
#     },
#     "45343": {
#         "forest_predict": {
#             "nao refatorar": 0.15,
#             "refatorar": 0.85
#         },
#         "shap": {
#             "features": [
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.14332161169559038,
#                     "feature_ranges": null,
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.06654824552903807,
#                     "feature_ranges": null,
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.06646625363235044,
#                     "feature_ranges": null,
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.047147771176400614,
#                     "feature_ranges": null,
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": 0.04584139612623714,
#                     "feature_ranges": null,
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.04552689635125442,
#                     "feature_ranges": null,
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": 0.02694551940038682,
#                     "feature_ranges": null,
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": 0.025504558557528836,
#                     "feature_ranges": null,
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodStringLiteralsQty",
#                     "peso_feature": 0.02418472647899579,
#                     "feature_ranges": null,
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": 0.016866295446847875,
#                     "feature_ranges": null,
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": 0.015358447970906441,
#                     "feature_ranges": null,
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodNumbersQty",
#                     "peso_feature": 0.009367451168481396,
#                     "feature_ranges": null,
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": 0.00783002436698856,
#                     "feature_ranges": null,
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodLoopQty",
#                     "peso_feature": 0.0074799922330103606,
#                     "feature_ranges": null,
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodTryCatchQty",
#                     "peso_feature": 0.0047115777457229354,
#                     "feature_ranges": null,
#                     "prioridade": 15
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.0012463355860067966,
#                     "feature_ranges": null,
#                     "prioridade": 16
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": 0.0008294048742944157,
#                     "feature_ranges": null,
#                     "prioridade": 17
#                 },
#                 {
#                     "nome_feature": "methodComparisonsQty",
#                     "peso_feature": 0.00024286798679042497,
#                     "feature_ranges": null,
#                     "prioridade": 18
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": 4.209015663368147e-05,
#                     "feature_ranges": null,
#                     "prioridade": 19
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5364074963320494,
#             "local_prediction": 0.4575001989895098,
#             "features": [
#                 {
#                     "nome_feature": "bugFixCount",
#                     "peso_feature": -0.25566573714540725,
#                     "feature_ranges": "bugFixCount > 18.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": 0.05202654323702824,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": 0.04330142361121177,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": 0.04084024246865992,
#                     "feature_ranges": "10.00 < methodLoc <= 25.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": -0.02551829121372247,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": 0.02265258558082305,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": 0.022031555295782095,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": 0.021424380823084958,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9609375,
#             "coverage": 0.0037,
#             "features": [
#                 {
#                     "nome_feature": "refactoringsInvolved",
#                     "peso_feature": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "prioridade": 1
#                 },
#                 {
#                     "nome_feature": "methodRfc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "prioridade": 2
#                 },
#                 {
#                     "nome_feature": "methodVariablesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "prioridade": 3
#                 },
#                 {
#                     "nome_feature": "methodAnonymousClassesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodAnonymousClassesQty <= 0.00",
#                     "prioridade": 4
#                 },
#                 {
#                     "nome_feature": "methodLoc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLoc > 10.00",
#                     "prioridade": 5
#                 },
#                 {
#                     "nome_feature": "methodLambdasQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodLambdasQty <= 0.00",
#                     "prioridade": 6
#                 },
#                 {
#                     "nome_feature": "methodSubClassesQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "prioridade": 7
#                 },
#                 {
#                     "nome_feature": "methodAssignmentsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodAssignmentsQty > 1.00",
#                     "prioridade": 8
#                 },
#                 {
#                     "nome_feature": "methodUniqueWordsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodUniqueWordsQty > 13.00",
#                     "prioridade": 9
#                 },
#                 {
#                     "nome_feature": "methodWmc",
#                     "peso_feature": null,
#                     "feature_ranges": "methodWmc > 2.00",
#                     "prioridade": 10
#                 },
#                 {
#                     "nome_feature": "methodMaxNestedBlocks",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMaxNestedBlocks > 0.00",
#                     "prioridade": 11
#                 },
#                 {
#                     "nome_feature": "methodReturnQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodReturnQty > 0.00",
#                     "prioridade": 12
#                 },
#                 {
#                     "nome_feature": "methodParenthesizedExpsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "prioridade": 13
#                 },
#                 {
#                     "nome_feature": "methodMathOperationsQty",
#                     "peso_feature": null,
#                     "feature_ranges": "methodMathOperationsQty <= 1.00",
#                     "prioridade": 14
#                 },
#                 {
#                     "nome_feature": "methodCbo",
#                     "peso_feature": null,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "prioridade": 15
#                 }
#             ]
#         }
#     }
# }

# %%
def extract_feature_names(json_features):
    extracted_feature_names = []
    for f in json_features:
        extracted_feature_names.append(f['nome_feature'])
    return extracted_feature_names

def get_info_by_feature_name(exp_f, feature_name):
    feature_obj = next(x for x in exp_f if x["nome_feature"] == feature_name)
    return feature_obj['peso_feature'], feature_obj['feature_ranges'], feature_obj['prioridade']

def compare_feature_weights(feature_value):
    if 'rank_shap' in feature_value and 'rank_lime' in feature_value and 'rank_anchors' in feature_value:
        return feature_value['rank_anchors'], feature_value['rank_shap'], feature_value['rank_lime']
    elif 'rank_shap' in feature_value and 'rank_lime' in feature_value:
        return feature_value['rank_shap'], feature_value['rank_lime']
    elif 'rank_shap' in feature_value and 'rank_anchors' in feature_value:
        return feature_value['rank_anchors'], feature_value['rank_shap']
    elif 'rank_lime' in feature_value and 'rank_anchors' in feature_value:
        return feature_value['rank_anchors'], feature_value['rank_lime']

def intersect_feature_explanations(feature_names, instancia):
    shap_f = instancia['shap']['features']
    lime_f = instancia['lime']['features']
    anchors_f = instancia['anchors']['features']

    shap_f_names = extract_feature_names(shap_f)
    lime_f_names = extract_feature_names(lime_f)
    anchors_f_names = extract_feature_names(anchors_f)

    intersec_3, intersec_shap_lime, intersec_shap_anchors, intersec_lime_anchors = ([] for i in range(4))
    resumo_intersec = dict()
    for f in feature_names:
        # for each configuration of intersection, gets feature name and explainers priority ranking
        # when finds feature in shap, lime and anchors
        if f in shap_f_names and f in lime_f_names and f in anchors_f_names:
            resumo_feature = dict()
            resumo_feature['nome_feature'] = f
            # get info from explainers' features
            _, anchors_ranges, anchors_priority = get_info_by_feature_name(anchors_f, f)
            shap_weight, _, shap_priority = get_info_by_feature_name(shap_f, f)
            lime_weight, lime_ranges, lime_priority = get_info_by_feature_name(lime_f, f)
            # puts in dictionary
            resumo_feature['rank_anchors'] = anchors_priority
            resumo_feature['rank_shap'] = shap_priority
            resumo_feature['rank_lime'] = lime_priority
            resumo_feature['peso_shap'] = shap_weight
            resumo_feature['peso_lime'] = lime_weight
            resumo_feature['range_anchors'] = anchors_ranges
            resumo_feature['range_lime'] = lime_ranges
            intersec_3.append(resumo_feature)
        # when finds feature in shap and lime
        elif f in shap_f_names and f in lime_f_names:
            resumo_feature = dict()
            resumo_feature['nome_feature'] = f
            # get info from explainers' features
            shap_weight, _, shap_priority = get_info_by_feature_name(shap_f, f)
            lime_weight, lime_ranges, lime_priority = get_info_by_feature_name(lime_f, f)
            resumo_feature['rank_shap'] = shap_priority
            resumo_feature['rank_lime'] = lime_priority
            resumo_feature['peso_shap'] = shap_weight
            resumo_feature['peso_lime'] = lime_weight
            resumo_feature['range_lime'] = lime_ranges
            intersec_shap_lime.append(resumo_feature)
        # when finds feature in shap and anchors
        elif f in shap_f_names and f in anchors_f_names:
            resumo_feature = dict()
            resumo_feature['nome_feature'] = f
            # get info from explainers' features
            _, anchors_ranges, anchors_priority = get_info_by_feature_name(anchors_f, f)
            shap_weight, _, shap_priority = get_info_by_feature_name(shap_f, f)
            # puts in dictionary
            resumo_feature['rank_anchors'] = anchors_priority
            resumo_feature['rank_shap'] = shap_priority
            resumo_feature['range_anchors'] = anchors_ranges
            resumo_feature['peso_shap'] = shap_weight
            intersec_shap_anchors.append(resumo_feature)
        # when finds feature in lime and anchors
        elif f in lime_f_names and f in anchors_f_names:
            resumo_feature = dict()
            resumo_feature['nome_feature'] = f
            # get info from explainers' features
            _, anchors_ranges, anchors_priority = get_info_by_feature_name(anchors_f, f)
            lime_weight, lime_ranges, lime_priority = get_info_by_feature_name(lime_f, f)
            # puts in dictionary
            resumo_feature['rank_anchors'] = anchors_priority
            resumo_feature['rank_lime'] = lime_priority
            resumo_feature['peso_lime'] = lime_weight
            resumo_feature['range_anchors'] = anchors_ranges
            resumo_feature['range_lime'] = lime_ranges
            intersec_lime_anchors.append(resumo_feature)

    # order each list by importance (1st anchors, 2nd shap, 3rd lime)
    resumo_intersec['intersec_all'] = sorted(intersec_3, key=compare_feature_weights)
    resumo_intersec['intersec_shap_lime'] = sorted(intersec_shap_lime, key=compare_feature_weights)
    resumo_intersec['intersec_shap_anchors'] = sorted(intersec_shap_anchors, key=compare_feature_weights)
    resumo_intersec['intersec_lime_anchors'] = sorted(intersec_lime_anchors, key=compare_feature_weights)
    
    # print(json.dumps(resumo_intersec, indent=4))
    return resumo_intersec

# %%
feature_names = list(amostras.columns)

# 1st: get interseccions between all the 3 explainers
# 2nd: get interseccions between 2 explainers
#      decision between explainers will have
#      priority -> 1 - anchors, 2 - shap, 3 - lime
def generate_top_n_features_v1(feature_names, json_out, n_f):
    final_explanations = dict()
    # run each instance
    for i in json_out:
        intersections = intersect_feature_explanations(feature_names, json_out[i])
        # 1st step of algorithm
        # get intersections between all explainers
        final_n_features = intersections['intersec_all'][0:n_f]
        # verify how many features misses to complete the x top features
        missing_features = n_f - len(final_n_features)
        order_remaining_features = []
        if missing_features:
            # get x reamining features from each of intersections between 2 explainers
            i_shap_lime_f = intersections['intersec_shap_lime'][0:missing_features]
            i_shap_anchors_f = intersections['intersec_shap_anchors'][0:missing_features]
            i_lime_anchors_f = intersections['intersec_lime_anchors'][0:missing_features]
            # concat lists
            remaining_features = i_shap_lime_f+i_shap_anchors_f+i_lime_anchors_f
            # 2st step of algorithm
            # sort concatenated list 
            order_remaining_features = sorted(remaining_features, key=compare_feature_weights)
        # concat features selected
        final_n_features = final_n_features + order_remaining_features[0:missing_features]
        final_explanations[i] = final_n_features
    return final_explanations

final_explanations = generate_top_n_features_v1(feature_names, json_output_exp, 5)
print(json.dumps(final_explanations, indent=4))
# Out:
# {
#     "60621": [
#         {
#             "nome_feature": "bugFixCount",
#             "rank_anchors": 1,
#             "rank_shap": 1,
#             "rank_lime": 1,
#             "peso_shap": 0.08669926474690005,
#             "peso_lime": 0.1367958122599585,
#             "range_anchors": "bugFixCount <= 4.00",
#             "range_lime": "0.00 < bugFixCount <= 4.00"
#         },
#         {
#             "nome_feature": "methodRfc",
#             "rank_anchors": 2,
#             "rank_shap": 3,
#             "rank_lime": 3,
#             "peso_shap": 0.05268806497404086,
#             "peso_lime": 0.053828724236807686,
#             "range_anchors": "methodRfc > 10.00",
#             "range_lime": "methodRfc > 10.00"
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_shap": 2,
#             "rank_lime": 2,
#             "peso_shap": 0.058553218067354224,
#             "peso_lime": 0.05520834638214641,
#             "range_lime": "methodLoc > 25.00"
#         },
#         {
#             "nome_feature": "refactoringsInvolved",
#             "rank_anchors": 3,
#             "rank_shap": 7,
#             "range_anchors": "refactoringsInvolved > 3.00",
#             "peso_shap": 0.01671722985781716
#         },
#         {
#             "nome_feature": "methodVariablesQty",
#             "rank_shap": 4,
#             "rank_lime": 4,
#             "peso_shap": 0.04076783238029673,
#             "peso_lime": 0.039378870041254316,
#             "range_lime": "methodVariablesQty > 3.00"
#         }
#     ],
#     "63330": [
#         {
#             "nome_feature": "bugFixCount",
#             "rank_anchors": 1,
#             "rank_shap": 1,
#             "rank_lime": 1,
#             "peso_shap": 0.13021479262833538,
#             "peso_lime": 0.14718916430725937,
#             "range_anchors": "bugFixCount <= 4.00",
#             "range_lime": "0.00 < bugFixCount <= 4.00"
#         },
#         {
#             "nome_feature": "methodUniqueWordsQty",
#             "rank_anchors": 2,
#             "rank_shap": 3,
#             "rank_lime": 5,
#             "peso_shap": 0.0627996083899755,
#             "peso_lime": 0.04755277224929207,
#             "range_anchors": "methodUniqueWordsQty > 26.00",
#             "range_lime": "methodUniqueWordsQty > 26.00"
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_shap": 2,
#             "rank_lime": 2,
#             "peso_shap": 0.07097727154387841,
#             "peso_lime": 0.060653022181763334,
#             "range_lime": "methodLoc > 25.00"
#         },
#         {
#             "nome_feature": "methodRfc",
#             "rank_shap": 4,
#             "rank_lime": 4,
#             "peso_shap": 0.04771967236981946,
#             "peso_lime": 0.05125915426907109,
#             "range_lime": "methodRfc > 10.00"
#         },
#         {
#             "nome_feature": "methodAssignmentsQty",
#             "rank_shap": 6,
#             "rank_lime": 8,
#             "peso_shap": 0.014113813400851773,
#             "peso_lime": 0.01806562630540506,
#             "range_lime": "1.00 < methodAssignmentsQty <= 5.00"
#         }
#     ],
#     "84054": [
#         {
#             "nome_feature": "refactoringsInvolved",
#             "rank_anchors": 1,
#             "rank_shap": 7,
#             "rank_lime": 5,
#             "peso_shap": 0.023494330325642125,
#             "peso_lime": 0.03656703168277713,
#             "range_anchors": "refactoringsInvolved > 13.00",
#             "range_lime": "refactoringsInvolved > 13.00"
#         },
#         {
#             "nome_feature": "methodRfc",
#             "rank_anchors": 2,
#             "rank_shap": 1,
#             "rank_lime": 2,
#             "peso_shap": 0.09323812651754765,
#             "peso_lime": 0.05140450116445657,
#             "range_anchors": "methodRfc > 10.00",
#             "range_lime": "methodRfc > 10.00"
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_shap": 2,
#             "rank_lime": 1,
#             "peso_shap": 0.08169952207141529,
#             "peso_lime": 0.05571868689699968,
#             "range_lime": "methodLoc > 25.00"
#         },
#         {
#             "nome_feature": "methodUniqueWordsQty",
#             "rank_shap": 3,
#             "rank_lime": 4,
#             "peso_shap": 0.06467839113109065,
#             "peso_lime": 0.04065260664252824,
#             "range_lime": "methodUniqueWordsQty > 26.00"
#         },
#         {
#             "nome_feature": "bugFixCount",
#             "rank_anchors": 3,
#             "rank_shap": 9,
#             "range_anchors": "bugFixCount <= 18.00",
#             "peso_shap": 0.01270010429436888
#         }
#     ],
#     "99548": [
#         {
#             "nome_feature": "refactoringsInvolved",
#             "rank_anchors": 1,
#             "rank_shap": 6,
#             "rank_lime": 5,
#             "peso_shap": 0.022135762856746746,
#             "peso_lime": 0.03996490613989282,
#             "range_anchors": "refactoringsInvolved > 13.00",
#             "range_lime": "refactoringsInvolved > 13.00"
#         },
#         {
#             "nome_feature": "methodRfc",
#             "rank_anchors": 2,
#             "rank_shap": 3,
#             "rank_lime": 2,
#             "peso_shap": 0.05147922708284845,
#             "peso_lime": 0.057348573452733385,
#             "range_anchors": "methodRfc > 10.00",
#             "range_lime": "methodRfc > 10.00"
#         },
#         {
#             "nome_feature": "methodVariablesQty",
#             "rank_anchors": 4,
#             "rank_shap": 5,
#             "rank_lime": 7,
#             "peso_shap": 0.023806360696720406,
#             "peso_lime": 0.023822431718561424,
#             "range_anchors": "methodVariablesQty > 3.00",
#             "range_lime": "methodVariablesQty > 3.00"
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_anchors": 5,
#             "rank_shap": 2,
#             "rank_lime": 3,
#             "peso_shap": 0.05632241360312517,
#             "peso_lime": 0.052005294588750584,
#             "range_anchors": "methodLoc > 25.00",
#             "range_lime": "methodLoc > 25.00"
#         },
#         {
#             "nome_feature": "methodAssignmentsQty",
#             "rank_anchors": 7,
#             "rank_shap": 4,
#             "rank_lime": 6,
#             "peso_shap": 0.03081937901053193,
#             "peso_lime": 0.033475690931671534,
#             "range_anchors": "methodAssignmentsQty > 1.00",
#             "range_lime": "methodAssignmentsQty > 5.00"
#         }
#     ],
#     "42623": [
#         {
#             "nome_feature": "methodRfc",
#             "rank_anchors": 2,
#             "rank_shap": 2,
#             "rank_lime": 1,
#             "peso_shap": 0.09286582525476964,
#             "peso_lime": 0.06039424100238056,
#             "range_anchors": "methodRfc > 10.00",
#             "range_lime": "methodRfc > 10.00"
#         },
#         {
#             "nome_feature": "methodCbo",
#             "rank_anchors": 5,
#             "rank_shap": 9,
#             "rank_lime": 7,
#             "peso_shap": 0.006618172243035008,
#             "peso_lime": -0.026580307619070414,
#             "range_anchors": "methodCbo > 5.00",
#             "range_lime": "methodCbo > 5.00"
#         },
#         {
#             "nome_feature": "bugFixCount",
#             "rank_anchors": 1,
#             "rank_shap": 3,
#             "range_anchors": "bugFixCount <= 18.00",
#             "peso_shap": 0.08418179569401699
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_shap": 1,
#             "rank_lime": 4,
#             "peso_shap": 0.09943747537281462,
#             "peso_lime": 0.04770058352549178,
#             "range_lime": "methodLoc > 25.00"
#         },
#         {
#             "nome_feature": "refactoringsInvolved",
#             "rank_anchors": 3,
#             "rank_shap": 6,
#             "range_anchors": "refactoringsInvolved > 3.00",
#             "peso_shap": 0.02161496512452916
#         }
#     ],
#     "62913": [
#         {
#             "nome_feature": "bugFixCount",
#             "rank_anchors": 1,
#             "rank_lime": 1,
#             "peso_lime": -0.2557800846496146,
#             "range_anchors": "bugFixCount > 18.00",
#             "range_lime": "bugFixCount > 18.00"
#         },
#         {
#             "nome_feature": "methodRfc",
#             "rank_shap": 1,
#             "rank_lime": 4,
#             "peso_shap": 0.06741885767215788,
#             "peso_lime": 0.0476362366060331,
#             "range_lime": "methodRfc > 10.00"
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_shap": 2,
#             "rank_lime": 3,
#             "peso_shap": 0.05196349764413738,
#             "peso_lime": 0.05135326209261229,
#             "range_lime": "methodLoc > 25.00"
#         },
#         {
#             "nome_feature": "methodMaxNestedBlocks",
#             "rank_anchors": 2,
#             "rank_shap": 12,
#             "range_anchors": "methodMaxNestedBlocks <= 1.00",
#             "peso_shap": 0.004284857368149526
#         },
#         {
#             "nome_feature": "methodUniqueWordsQty",
#             "rank_shap": 3,
#             "rank_lime": 2,
#             "peso_shap": 0.045098165489465596,
#             "peso_lime": 0.052426124936734375,
#             "range_lime": "methodUniqueWordsQty > 26.00"
#         }
#     ],
#     "64822": [
#         {
#             "nome_feature": "bugFixCount",
#             "rank_anchors": 1,
#             "rank_shap": 1,
#             "rank_lime": 1,
#             "peso_shap": 0.09076048086079677,
#             "peso_lime": 0.1079025183647884,
#             "range_anchors": "bugFixCount <= 0.00",
#             "range_lime": "bugFixCount <= 0.00"
#         },
#         {
#             "nome_feature": "methodVariablesQty",
#             "rank_anchors": 2,
#             "rank_shap": 4,
#             "rank_lime": 8,
#             "peso_shap": 0.0433356934729825,
#             "peso_lime": 0.022271090306157613,
#             "range_anchors": "methodVariablesQty > 3.00",
#             "range_lime": "methodVariablesQty > 3.00"
#         },
#         {
#             "nome_feature": "methodUniqueWordsQty",
#             "rank_shap": 2,
#             "rank_lime": 2,
#             "peso_shap": 0.0640324772455129,
#             "peso_lime": 0.051186065771840955,
#             "range_lime": "methodUniqueWordsQty > 26.00"
#         },
#         {
#             "nome_feature": "refactoringsInvolved",
#             "rank_anchors": 3,
#             "rank_shap": 3,
#             "range_anchors": "refactoringsInvolved > 1.00",
#             "peso_shap": 0.04499364746868278
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_shap": 5,
#             "rank_lime": 3,
#             "peso_shap": 0.04143820873113514,
#             "peso_lime": 0.02818980600835778,
#             "range_lime": "10.00 < methodLoc <= 25.00"
#         }
#     ],
#     "833560": [
#         {
#             "nome_feature": "refactoringsInvolved",
#             "rank_anchors": 1,
#             "rank_shap": 6,
#             "rank_lime": 4,
#             "peso_shap": 0.015298521758291932,
#             "peso_lime": 0.0453099694713479,
#             "range_anchors": "refactoringsInvolved > 13.00",
#             "range_lime": "refactoringsInvolved > 13.00"
#         },
#         {
#             "nome_feature": "methodRfc",
#             "rank_anchors": 2,
#             "rank_shap": 1,
#             "rank_lime": 2,
#             "peso_shap": 0.08153975998544344,
#             "peso_lime": 0.049962813063946926,
#             "range_anchors": "methodRfc > 10.00",
#             "range_lime": "methodRfc > 10.00"
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_shap": 2,
#             "rank_lime": 3,
#             "peso_shap": 0.0733552908106066,
#             "peso_lime": 0.04846156147795708,
#             "range_lime": "methodLoc > 25.00"
#         },
#         {
#             "nome_feature": "methodAssignmentsQty",
#             "rank_shap": 3,
#             "rank_lime": 5,
#             "peso_shap": 0.05995468528973779,
#             "peso_lime": 0.03863034358080576,
#             "range_lime": "methodAssignmentsQty > 5.00"
#         },
#         {
#             "nome_feature": "bugFixCount",
#             "rank_anchors": 3,
#             "rank_shap": 10,
#             "range_anchors": "bugFixCount <= 18.00",
#             "peso_shap": 0.007199724792369284
#         }
#     ],
#     "45080": [
#         {
#             "nome_feature": "bugFixCount",
#             "rank_anchors": 1,
#             "rank_shap": 1,
#             "rank_lime": 1,
#             "peso_shap": 0.11294127770177226,
#             "peso_lime": 0.1532614319018238,
#             "range_anchors": "bugFixCount <= 4.00",
#             "range_lime": "0.00 < bugFixCount <= 4.00"
#         },
#         {
#             "nome_feature": "methodUniqueWordsQty",
#             "rank_anchors": 2,
#             "rank_shap": 4,
#             "rank_lime": 4,
#             "peso_shap": 0.06369349796635064,
#             "peso_lime": 0.0473477696392469,
#             "range_anchors": "methodUniqueWordsQty > 26.00",
#             "range_lime": "methodUniqueWordsQty > 26.00"
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_shap": 2,
#             "rank_lime": 3,
#             "peso_shap": 0.07572264281278833,
#             "peso_lime": 0.05177623953935548,
#             "range_lime": "methodLoc > 25.00"
#         },
#         {
#             "nome_feature": "methodRfc",
#             "rank_shap": 3,
#             "rank_lime": 2,
#             "peso_shap": 0.07390051978880398,
#             "peso_lime": 0.05181390879933978,
#             "range_lime": "methodRfc > 10.00"
#         },
#         {
#             "nome_feature": "refactoringsInvolved",
#             "rank_anchors": 3,
#             "rank_shap": 7,
#             "range_anchors": "refactoringsInvolved > 3.00",
#             "peso_shap": 0.016973560058933967
#         }
#     ],
#     "45343": [
#         {
#             "nome_feature": "refactoringsInvolved",
#             "rank_anchors": 1,
#             "rank_shap": 4,
#             "rank_lime": 3,
#             "peso_shap": 0.047147771176400614,
#             "peso_lime": 0.04330142361121177,
#             "range_anchors": "refactoringsInvolved > 13.00",
#             "range_lime": "refactoringsInvolved > 13.00"
#         },
#         {
#             "nome_feature": "methodRfc",
#             "rank_anchors": 2,
#             "rank_shap": 1,
#             "rank_lime": 2,
#             "peso_shap": 0.14332161169559038,
#             "peso_lime": 0.05202654323702824,
#             "range_anchors": "methodRfc > 10.00",
#             "range_lime": "methodRfc > 10.00"
#         },
#         {
#             "nome_feature": "methodVariablesQty",
#             "rank_anchors": 3,
#             "rank_shap": 6,
#             "rank_lime": 8,
#             "peso_shap": 0.04552689635125442,
#             "peso_lime": 0.021424380823084958,
#             "range_anchors": "methodVariablesQty > 3.00",
#             "range_lime": "methodVariablesQty > 3.00"
#         },
#         {
#             "nome_feature": "methodLoc",
#             "rank_anchors": 5,
#             "rank_shap": 3,
#             "rank_lime": 4,
#             "peso_shap": 0.06646625363235044,
#             "peso_lime": 0.04084024246865992,
#             "range_anchors": "methodLoc > 10.00",
#             "range_lime": "10.00 < methodLoc <= 25.00"
#         },
#         {
#             "nome_feature": "methodSubClassesQty",
#             "rank_anchors": 7,
#             "rank_shap": 19,
#             "rank_lime": 5,
#             "peso_shap": 4.209015663368147e-05,
#             "peso_lime": -0.02551829121372247,
#             "range_anchors": "methodSubClassesQty <= 0.00",
#             "range_lime": "methodSubClassesQty <= 0.00"
#         }
#     ]
# }
