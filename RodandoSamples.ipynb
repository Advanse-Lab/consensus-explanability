# %% [markdown]
# # First Steps

# %% [markdown]
# ## Importing Libraries

# %%
#!pip install --quiet -r requirements.txt

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for statistical data visualization
# %matplotlib inline
from ExKMC.Tree import Tree
from IPython.display import Image

np.random.seed(1)
import sys

import sklearn
import sklearn.ensemble
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

import shap
import joblib as jbl

import lime
import lime.lime_tabular

from anchor import utils
from anchor import anchor_tabular

import json
import warnings
# Out:
# /tmp/ipykernel_126983/1131581040.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ## Importing dataset and running Random Forest

# %%
# importing training dataset
data = pd.read_csv("21092023_Dataset_40k.csv")
data = data.set_index("id_")

# %%
# importing samples to explain
samples = pd.read_csv("Amostra-Dataset.csv")
# getting samples ids
samples_indexes = samples['id_'].to_list()
print(samples_indexes)

samples = samples.set_index("id_")
display(samples)
# Out:
# [60621, 63330, 84054, 99548, 42623, 62913, 64822, 833560, 45080, 45343]
#         methodAnonymousClassesQty  methodAssignmentsQty  methodCbo  \
# id_
# 60621                           0                     9          1
# 63330                           1                     4         13
# 84054                           0                    13         10
# 99548                           1                    12         10
# 42623                           0                     0          9
# 62913                           1                    13          9
# 64822                           0                    14         22
# 833560                          1                    19         14
# 45080                           0                    22         12
# 45343                           0                     4         12
#
#         methodComparisonsQty  methodLambdasQty  methodLoc  methodLoopQty  \
# id_
# 60621                      0                 0         77              0
# 63330                      0                 0         41              3
# 84054                      4                 0         44              0
# 99548                      0                 0         40              0
# 42623                      0                 0         44              0
# 62913                      2                 0         41              0
# 64822                      1                 0         18              0
# 833560                     3                 0         48              0
# 45080                      0                 2         50              0
# 45343                      0                 0         22              0
#
#         methodMathOperationsQty  methodMaxNestedBlocks  methodNumbersQty  ...  \
# id_                                                                       ...
# 60621                        64                      1                59  ...
# 63330                         0                      1                 0  ...
# 84054                         0                      1                 0  ...
# 99548                         0                      1                 0  ...
# 42623                         0                      1                 0  ...
# 62913                         0                      1                 0  ...
# 64822                         0                      1                 0  ...
# 833560                        4                      1                 6  ...
# 45080                         0                      1                 2  ...
# 45343                         0                      1                 1  ...
#
#         methodReturnQty  methodRfc  methodStringLiteralsQty  \
# id_
# 60621                 0         32                        0
# 63330                 1         12                        6
# 84054                 5         17                        0
# 99548                 1         17                        0
# 42623                14         11                        2
# 62913                 0         17                        3
# 64822                 1          4                        0
# 833560                3         21                        3
# 45080                 0         26                        0
# 45343                 2         23                        0
#
#         methodSubClassesQty  methodTryCatchQty  methodUniqueWordsQty  \
# id_
# 60621                     0                  0                    22
# 63330                     0                  0                    36
# 84054                     0                  0                    32
# 99548                     0                  1                    52
# 42623                     0                  0                    35
# 62913                     0                  0                    48
# 64822                     0                  0                    52
# 833560                    0                  0                    56
# 45080                     0                  0                    48
# 45343                     0                  0                    24
#
#         methodVariablesQty  methodWmc  bugFixCount  refactoringsInvolved
# id_
# 60621                    8          4            4                     4
# 63330                    3          6            3                    11
# 84054                   10          9           13                    42
# 99548                    8          4           51                    30
# 42623                    0         14            7                    13
# 62913                    2          7          172                    67
# 64822                   14          1            0                     8
# 833560                  17          6           13                    24
# 45080                   12          4            2                     8
# 45343                    4          4           60                    25
#
# [10 rows x 22 columns]

# %%
# splitting train and test
X = data.drop(['y'], axis=1)
y = data['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# training random forest model
forest = RandomForestClassifier(random_state=0)
forest.fit(X_train, y_train)

# getting list of feature names
feature_names = list(X_train.columns)

# %% [markdown]
# ## Setting up explainers

# %%
# Importando shap
try:
    with open("./" + 'shap_explainer', 'rb') as f:
        explainer_shap = jbl.load(f)
except:
    explainer_shap = shap.TreeExplainer(forest)
    with open("./" + 'shap_explainer', 'wb') as f:
        jbl.dump(explainer_shap, f)

# %%
# LIME has one explainer for all the models
explainer_lime = lime.lime_tabular.LimeTabularExplainer(X_train.values, feature_names=X_train.columns.values.tolist(), class_names=[0, 1], verbose=True, mode='classification',  discretize_continuous=True)

# %%
explainer_anchors = anchor_tabular.AnchorTabularExplainer(
    [0, 1],
    X_train.columns.values.tolist(),
    X_train.values,
    {})

# %% [markdown]
# # Running instances and showing graphs

# %%
# function to show explicability methods graphs
def instance_local_explanations(i, samples):
    # show row content
    print("Instance n°: ", samples_indexes[i])
    print(samples.iloc[i])
    print("Random Forest Prediction: ", forest.predict_proba(samples.iloc[[i]]))
    
    #SHAP explainer
    print("SHAP")
    row = samples.iloc[i]
    to_predict = row.values.reshape(1, -1)
    forest_prediction = sum(forest.predict_proba(to_predict))
    shap_values = explainer_shap.shap_values(row)
    shap.initjs()
    display(shap.force_plot(explainer_shap.expected_value[1], shap_values[1], row))
    # shap_output = export_shap_exp(i, forest_prediction[1], explainer_shap.expected_value, shap_values)
    # shap_exps.join(shap_output)
    # shap_result = pd.concat([shap_exps, shap_output], ignore_index=True)

    #LIME explainer
    print("LIME")
    exp_lime = explainer_lime.explain_instance(samples.values[i], forest.predict_proba, num_features=8)
    exp_lime.show_in_notebook(show_table=True)
    # lime_output = export_lime_exp(i, forest_prediction[1], exp_lime.intercept[1], exp_lime.local_pred, exp_lime.as_list())
    # lime_exps.join(lime_output)
    # lime_result = pd.concat([lime_exps, lime_output], ignore_index=True)

    #ANCHORS explainer
    print("ANCHORS")
    exp_anchors = explainer_anchors.explain_instance(samples.values[i], forest.predict, threshold=0.95)
    print('Anchor: %s' % (' AND '.join(exp_anchors.names())))
    print('Precision: %.2f' % exp_anchors.precision())
    print('Coverage: %.2f' % exp_anchors.coverage())
    exp_anchors.show_in_notebook()

    print("-----------------------------------------------------------------------------------------------")

# %% [markdown]
# # Exporting explanations

# %% [markdown]
# ## File format .json

# %% [markdown]
# ### Export features e General data of each explainer

# %%
# function to help sorting features
def compare_shap_feature_weights(feature_value):
    # highest weights first
    return -feature_value['feature_weight']

# export shap features' explanations
def export_shap_exp(row, feature_names, shap_values):
    # get shap values to refactor instance
    shap_values_to_refactor = shap_values[1]
    shap_output = dict()
    
    features_exp = []
    for i in range(0, len(feature_names)):
        # shap_values has positive values (to refactor) and negative ones (not to refactor)
        if shap_values_to_refactor[i] > 0:
            f = dict()
            feature_name = feature_names[i]
            f['feature_name'] = feature_name
            f['feature_value'] = int(row[feature_name])
            f['feature_weight'] = shap_values_to_refactor[i]
            f['feature_ranges'] = None
            features_exp.append(f)
    # sort features by feature weight
    sorted_features_exp = sorted(features_exp, key=compare_shap_feature_weights)
    # append feature ranking after sort
    rank = 1
    for f in sorted_features_exp:
        f['feature_rank'] = rank
        rank = rank + 1
    shap_output['features'] = sorted_features_exp
    return shap_output

# export lime features' explanations
def export_lime_exp(row, feature_names, exp_lime):
    lime_output = dict()
    # general instance indices
    lime_output['intercept'] = exp_lime.intercept[1]
    lime_output['local_prediction'] = exp_lime.local_pred[0]
    lime_features = exp_lime.as_list()
    # features' values
    features_exp = []
    rank = 1
    for value in lime_features:
        # value[1] (feature_weight) has positive values (to refactor) and negative ones (not to refactor)
        if value[1] > 0:
            f = dict()
            # extract feature name from feature ranges string
            any((feature_name := substring) in value[0] for substring in feature_names)
            f['feature_name'] = feature_name
            f['feature_value'] = int(row[feature_name])
            f['feature_weight'] = value[1]
            f['feature_ranges'] = value[0]
            f['feature_rank'] = rank # feature's order of priority in explainer's result
            features_exp.append(f)
            rank = rank + 1 # ranks the positive features
    lime_output['features'] = features_exp
    return lime_output

# export anchors features' explanations
def export_anchors_exp(row, feature_names, anchors_exp):
    anchors_output = dict()
    # general instance indices
    anchors_output['precision'] = anchors_exp.precision()
    anchors_output['coverage'] = anchors_exp.coverage()
    # features' values
    features_exp = []
    rank = 1
    for name in anchors_exp.names():
        f = dict()
        # extract feature name from anchors' names string
        any((feature_name := substring) in str(name) for substring in feature_names)
        f['feature_name'] = feature_name
        f['feature_value'] = int(row[feature_name])
        f['feature_weight'] = None
        f['feature_ranges'] = name
        f['feature_rank'] = rank # feature's order of priority in explainer's result
        features_exp.append(f)
        rank = rank + 1
    anchors_output['features'] = features_exp
    return anchors_output

# %% [markdown]
# ### Run explainers for a samples dataset and export each one

# %%
def run_and_export_explainers(samples, i):
    feature_names = list(samples.columns)
    
    #SHAP
    row = samples.iloc[i]
    shap_values = explainer_shap.shap_values(row)
    shap_output = export_shap_exp(row, feature_names, shap_values)

    #LIME
    exp_lime = explainer_lime.explain_instance(samples.values[i], forest.predict_proba, num_features=8)
    lime_output = export_lime_exp(row, feature_names, exp_lime)

    #ANCHORS
    exp_anchors = explainer_anchors.explain_instance(samples.values[i], forest.predict, threshold=0.95)
    anchors_output = export_anchors_exp(row, feature_names, exp_anchors)
    
    return [shap_output, lime_output, anchors_output]

# %% [markdown]
# ### Junta as explicações em um json com dados da instância

# %%
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
def export_json_explanations(samples, indexes):
    explanations = dict()
    for i in range(0, len(samples)):
        json_output = {}
        # gives values of random forest predictions
        predict = forest.predict_proba(samples.iloc[[i]])[0]
        json_output['forest_prediction'] = {'not to refactor': predict[0], 'refactor': predict[1]}
        # calls funtions that run and export shap, lime and anchors explanations
        json_output['shap'], json_output['lime'], json_output['anchors'] = run_and_export_explainers(samples, i)
        # puts explanations in each instance index
        explanations[indexes[i]] = json_output
        #export explanations to json file
    with open("explanations_samples.json", "w") as outfile:
        json.dump(explanations, outfile)
    return explanations

json_output_exp = export_json_explanations(samples, samples_indexes)
#pretty print for json
print(json.dumps(json_output_exp, indent=4))
# Out:
# Intercept 0.3983520684376731
# Prediction_local [0.75947097]
# Right: 0.72
# Intercept 0.3736842713337413
# Prediction_local [0.7365066]
# Right: 0.81
# Intercept 0.3891187709623613
# Prediction_local [0.69890339]
# Right: 0.97
# Intercept 0.44525973239188626
# Prediction_local [0.51345533]
# Right: 0.51
# Intercept 0.48349241309973656
# Prediction_local [0.59197496]
# Right: 0.9
# Intercept 0.5326300635890906
# Prediction_local [0.49365503]
# Right: 0.49
# Intercept 0.43409841612312483
# Prediction_local [0.67863806]
# Right: 0.8
# Intercept 0.43709530683567177
# Prediction_local [0.6940152]
# Right: 0.84
# Intercept 0.4650824269670306
# Prediction_local [0.7842747]
# Right: 0.98
# Intercept 0.43887803221331567
# Prediction_local [0.43054244]
# Right: 0.85
# {
#     "60621": {
#         "forest_prediction": {
#             "not to refactor": 0.28,
#             "refactor": 0.72
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 4,
#                     "feature_weight": 0.08669926474690005,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 77,
#                     "feature_weight": 0.058553218067354224,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 32,
#                     "feature_weight": 0.05268806497404086,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": 0.04076783238029673,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 22,
#                     "feature_weight": 0.028932669857590992,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 9,
#                     "feature_weight": 0.026450348447629835,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 4,
#                     "feature_weight": 0.01671722985781716,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.012766059664577023,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": 0.011116257148607969,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.010156880433909029,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.001827909114364533,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0003608535201939072,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": 9.084629673378033e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 4.4078172909521527e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.3983520684376731,
#             "local_prediction": 0.7594709687658169,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 4,
#                     "feature_weight": 0.1481879078667768,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.05884676793030231,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 32,
#                     "feature_weight": 0.05023540236417073,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 77,
#                     "feature_weight": 0.04518449733663578,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 9,
#                     "feature_weight": 0.03924463740749026,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": 0.024416264069075943,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 22,
#                     "feature_weight": 0.023486154130838193,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00",
#                     "feature_rank": 7
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9689119170984456,
#             "coverage": 0.0325,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 32,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "feature_rank": 3
#                 }
#             ]
#         }
#     },
#     "63330": {
#         "forest_prediction": {
#             "not to refactor": 0.19,
#             "refactor": 0.81
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 3,
#                     "feature_weight": 0.13021479262833538,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 41,
#                     "feature_weight": 0.07097727154387841,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 36,
#                     "feature_weight": 0.0627996083899755,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 12,
#                     "feature_weight": 0.04771967236981946,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 3,
#                     "feature_weight": 0.015180589342788542,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.014113813400851773,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 1,
#                     "feature_weight": 0.011545676016778798,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 6,
#                     "feature_weight": 0.011428481808361405,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.003006743404812675,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0024517770819787498,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0018663813346113942,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.001320897685854606,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0009781818281547202,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00047334695391865574,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 7.491428865380632e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.3736842713337413,
#             "local_prediction": 0.7365066037435373,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 3,
#                     "feature_weight": 0.14834476392584509,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 41,
#                     "feature_weight": 0.05586231371387346,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.051253004456258716,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 12,
#                     "feature_weight": 0.05116029399791379,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 36,
#                     "feature_weight": 0.04280026732909047,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 6,
#                     "feature_weight": 0.020631890639955644,
#                     "feature_ranges": "methodWmc > 5.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.017380301692683137,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "feature_rank": 7
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9732824427480916,
#             "coverage": 0.0333,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 3,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 12,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 11,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "feature_rank": 3
#                 }
#             ]
#         }
#     },
#     "84054": {
#         "forest_prediction": {
#             "not to refactor": 0.03,
#             "refactor": 0.97
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.09323812651754765,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 44,
#                     "feature_weight": 0.08169952207141529,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 32,
#                     "feature_weight": 0.06467839113109065,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 13,
#                     "feature_weight": 0.052016565430834535,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 10,
#                     "feature_weight": 0.05148640570651179,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 9,
#                     "feature_weight": 0.02571147744757186,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 42,
#                     "feature_weight": 0.023494330325642125,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 10,
#                     "feature_weight": 0.01323758524458843,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 13,
#                     "feature_weight": 0.01270010429436888,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.010818958052815056,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.010113086954582563,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.008729147639901638,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.005691258159848672,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.004112374348361524,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.0037197854784388547,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0036308162217063016,
#                     "feature_ranges": null,
#                     "feature_rank": 16
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0034852486341215437,
#                     "feature_ranges": null,
#                     "feature_rank": 17
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0017564105935530478,
#                     "feature_ranges": null,
#                     "feature_rank": 18
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0008450124229482799,
#                     "feature_ranges": null,
#                     "feature_rank": 19
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0002970828696750368,
#                     "feature_ranges": null,
#                     "feature_rank": 20
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 3.0586680700167566e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 21
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.3891187709623613,
#             "local_prediction": 0.6989033850176736,
#             "features": [
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.05455932836409966,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 44,
#                     "feature_weight": 0.05070231825371531,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.046475950233913745,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 42,
#                     "feature_weight": 0.045562367169588,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 32,
#                     "feature_weight": 0.04462041581274514,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 13,
#                     "feature_weight": 0.0287957645230252,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 10,
#                     "feature_weight": 0.022179456388699424,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.016889013309525778,
#                     "feature_ranges": "methodStringLiteralsQty <= 0.00",
#                     "feature_rank": 8
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9694656488549618,
#             "coverage": 0.0084,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 13,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 18.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 44,
#                     "feature_weight": null,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 42,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodReturnQty",
#                     "feature_value": 5,
#                     "feature_weight": null,
#                     "feature_ranges": "methodReturnQty > 0.00",
#                     "feature_rank": 4
#                 }
#             ]
#         }
#     },
#     "99548": {
#         "forest_prediction": {
#             "not to refactor": 0.49,
#             "refactor": 0.51
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 52,
#                     "feature_weight": 0.07082448762246794,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 40,
#                     "feature_weight": 0.05632241360312517,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.05147922708284845,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 12,
#                     "feature_weight": 0.03081937901053193,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": 0.023806360696720406,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 30,
#                     "feature_weight": 0.022135762856746746,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.014684854764444527,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": 0.005221040363847994,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 10,
#                     "feature_weight": 0.004571488265823622,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.003843254451027073,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.003409350810319622,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0033611188150419833,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.0023739205365156464,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0012453822970158739,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 3.796730653958034e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.44525973239188626,
#             "local_prediction": 0.5134553307805644,
#             "features": [
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.06766512468385802,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.054752680189826056,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 40,
#                     "feature_weight": 0.052335297335246195,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 52,
#                     "feature_weight": 0.05061062090732389,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 30,
#                     "feature_weight": 0.046114312541648585,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": 0.029260320738399046,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 12,
#                     "feature_weight": 0.025625136788221734,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "feature_rank": 7
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9567099567099567,
#             "coverage": 0.0016,
#             "features": [
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 30,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 40,
#                     "feature_weight": null,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": null,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodLoopQty <= 0.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 10,
#                     "feature_weight": null,
#                     "feature_ranges": "methodCbo > 2.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "methodWmc > 2.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": null,
#                     "feature_ranges": "methodMaxNestedBlocks > 0.00",
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 52,
#                     "feature_weight": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 12,
#                     "feature_weight": null,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodLambdasQty <= 0.00",
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodMathOperationsQty <= 1.00",
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodStringLiteralsQty <= 2.00",
#                     "feature_rank": 14
#                 }
#             ]
#         }
#     },
#     "42623": {
#         "forest_prediction": {
#             "not to refactor": 0.1,
#             "refactor": 0.9
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 44,
#                     "feature_weight": 0.09943747537281462,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 11,
#                     "feature_weight": 0.09286582525476964,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 7,
#                     "feature_weight": 0.08418179569401699,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 35,
#                     "feature_weight": 0.07632619693015875,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 14,
#                     "feature_weight": 0.03626241164610176,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 13,
#                     "feature_weight": 0.02161496512452916,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 1,
#                     "feature_weight": 0.012627762278196857,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.009847588831970124,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 9,
#                     "feature_weight": 0.006618172243035008,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0063962228434345314,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.0063908325198334896,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.004174637288898191,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.002516242300954705,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0021351196095788848,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.001583891659593615,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0002566526803513638,
#                     "feature_ranges": null,
#                     "feature_rank": 16
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00016728699148169378,
#                     "feature_ranges": null,
#                     "feature_rank": 17
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 5.2923896729520325e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 18
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.48349241309973656,
#             "local_prediction": 0.5919749564320025,
#             "features": [
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 35,
#                     "feature_weight": 0.052042952543613984,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 11,
#                     "feature_weight": 0.051072512459777474,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 44,
#                     "feature_weight": 0.044772270762823474,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 14,
#                     "feature_weight": 0.01933834121648025,
#                     "feature_ranges": "methodWmc > 5.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0183352806654625,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "feature_rank": 5
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9586114819759679,
#             "coverage": 0.029,
#             "features": [
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 13,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 11,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 7,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 18.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 9,
#                     "feature_weight": null,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 1,
#                     "feature_weight": null,
#                     "feature_ranges": "methodParametersQty <= 2.00",
#                     "feature_rank": 5
#                 }
#             ]
#         }
#     },
#     "62913": {
#         "forest_prediction": {
#             "not to refactor": 0.51,
#             "refactor": 0.49
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.06741885767215788,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 41,
#                     "feature_weight": 0.05196349764413738,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 48,
#                     "feature_weight": 0.045098165489465596,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 13,
#                     "feature_weight": 0.03493254310843103,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 3,
#                     "feature_weight": 0.018377924610596556,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.013394203873891907,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 3,
#                     "feature_weight": 0.009010479897717283,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 1,
#                     "feature_weight": 0.008345431115244654,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 9,
#                     "feature_weight": 0.007677328858526726,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 67,
#                     "feature_weight": 0.007246656651782406,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.00526291791656694,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.004284857368149526,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
# ...
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 26,
#                     "feature_weight": 0.055499394545169466,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 48,
#                     "feature_weight": 0.04524492044685938,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 22,
#                     "feature_weight": 0.028049420431279757,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 12,
#                     "feature_weight": 0.024074037655989644,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.023556383687376156,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "feature_rank": 7
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9574468085106383,
#             "coverage": 0.07,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 2,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 12,
#                     "feature_weight": null,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 8,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 1.00",
#                     "feature_rank": 3
#                 }
#             ]
#         }
#     },
#     "45343": {
#         "forest_prediction": {
#             "not to refactor": 0.15,
#             "refactor": 0.85
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 23,
#                     "feature_weight": 0.14332161169559038,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 24,
#                     "feature_weight": 0.06654824552903807,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 22,
#                     "feature_weight": 0.06646625363235044,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 25,
#                     "feature_weight": 0.047147771176400614,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.04584139612623714,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.04552689635125442,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 12,
#                     "feature_weight": 0.02694551940038682,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": 0.025504558557528836,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.02418472647899579,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.016866295446847875,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodReturnQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.015358447970906441,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 1,
#                     "feature_weight": 0.009367451168481396,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00783002436698856,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0074799922330103606,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0047115777457229354,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0012463355860067966,
#                     "feature_ranges": null,
#                     "feature_rank": 16
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0008294048742944157,
#                     "feature_ranges": null,
#                     "feature_rank": 17
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00024286798679042497,
#                     "feature_ranges": null,
#                     "feature_rank": 18
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 4.209015663368147e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 19
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.43887803221331567,
#             "local_prediction": 0.43054244290306803,
#             "features": [
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.10041492113605958,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 25,
#                     "feature_weight": 0.04970610778093022,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 23,
#                     "feature_weight": 0.041277280392909454,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.03070432162417648,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 22,
#                     "feature_weight": 0.030232332453153564,
#                     "feature_ranges": "10.00 < methodLoc <= 25.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 24,
#                     "feature_weight": 0.021292368720183447,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00",
#                     "feature_rank": 6
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9453924914675768,
#             "coverage": 0.0,
#             "features": [
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 25,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 23,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodMathOperationsQty <= 0.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "2.00 < methodWmc <= 5.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodLambdasQty <= 0.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 24,
#                     "feature_weight": null,
#                     "feature_ranges": "methodUniqueWordsQty > 13.00",
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "1.00 < methodAssignmentsQty <= 5.00",
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 22,
#                     "feature_weight": null,
#                     "feature_ranges": "10.00 < methodLoc <= 25.00",
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": null,
#                     "feature_ranges": "0.00 < methodMaxNestedBlocks <= 2.00",
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 12,
#                     "feature_weight": null,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodReturnQty",
#                     "feature_value": 2,
#                     "feature_weight": null,
#                     "feature_ranges": "methodReturnQty > 0.00",
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodTryCatchQty <= 0.00",
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "feature_rank": 15
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodAnonymousClassesQty <= 0.00",
#                     "feature_rank": 16
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodStringLiteralsQty <= 0.00",
#                     "feature_rank": 17
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodComparisonsQty <= 0.00",
#                     "feature_rank": 18
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 1,
#                     "feature_weight": null,
#                     "feature_ranges": "methodNumbersQty <= 1.00",
#                     "feature_rank": 19
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodLoopQty <= 0.00",
#                     "feature_rank": 20
#                 }
#             ]
#         }
#     }
# }

# %% [markdown]
# ## File format .csv

# %%
# shap_output = pd.DataFrame()
# lime_output = pd.DataFrame()
# for i in range(0,10):
#     (shap_output, lime_output) = instance_local_explanations(i, samples, shap_output, lime_output)
# shap_output.to_csv('shap_explanations.csv')
# lime_output.to_csv('lime_explanations.csv')

# %% [markdown]
# # Analysing explanations

# %%
print(json.dumps(json_output_exp, indent=4))
# Out:
# {
#     "60621": {
#         "forest_prediction": {
#             "not to refactor": 0.28,
#             "refactor": 0.72
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 4,
#                     "feature_weight": 0.08669926474690005,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 77,
#                     "feature_weight": 0.058553218067354224,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 32,
#                     "feature_weight": 0.05268806497404086,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": 0.04076783238029673,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 22,
#                     "feature_weight": 0.028932669857590992,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 9,
#                     "feature_weight": 0.026450348447629835,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 4,
#                     "feature_weight": 0.01671722985781716,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.012766059664577023,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": 0.011116257148607969,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.010156880433909029,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.001827909114364533,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0003608535201939072,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": 9.084629673378033e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 4.4078172909521527e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.4349535690065091,
#             "local_prediction": 0.7773191454422511,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 4,
#                     "feature_weight": 0.1367958122599585,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 77,
#                     "feature_weight": 0.05520834638214641,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 32,
#                     "feature_weight": 0.053828724236807686,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": 0.039378870041254316,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 22,
#                     "feature_weight": 0.027762194358496747,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 9,
#                     "feature_weight": 0.02409377329320792,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.019359931506358136,
#                     "feature_ranges": "methodParametersQty <= 0.00",
#                     "feature_rank": 7
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9708029197080292,
#             "coverage": 0.0348,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 32,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "feature_rank": 3
#                 }
#             ]
#         }
#     },
#     "63330": {
#         "forest_prediction": {
#             "not to refactor": 0.19,
#             "refactor": 0.81
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 3,
#                     "feature_weight": 0.13021479262833538,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 41,
#                     "feature_weight": 0.07097727154387841,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 36,
#                     "feature_weight": 0.0627996083899755,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 12,
#                     "feature_weight": 0.04771967236981946,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 3,
#                     "feature_weight": 0.015180589342788542,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.014113813400851773,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 1,
#                     "feature_weight": 0.011545676016778798,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 6,
#                     "feature_weight": 0.011428481808361405,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.003006743404812675,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0024517770819787498,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0018663813346113942,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.001320897685854606,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0009781818281547202,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00047334695391865574,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 7.491428865380632e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.3607798134139092,
#             "local_prediction": 0.7451932658708532,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 3,
#                     "feature_weight": 0.14718916430725937,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 41,
#                     "feature_weight": 0.060653022181763334,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.05585164050870991,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 12,
#                     "feature_weight": 0.05125915426907109,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 36,
#                     "feature_weight": 0.04755277224929207,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.022759488264913235,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.01806562630540506,
#                     "feature_ranges": "1.00 < methodAssignmentsQty <= 5.00",
#                     "feature_rank": 7
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9635761589403974,
#             "coverage": 0.0345,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 3,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 36,
#                     "feature_weight": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 11,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "feature_rank": 3
#                 }
#             ]
#         }
#     },
#     "84054": {
#         "forest_prediction": {
#             "not to refactor": 0.03,
#             "refactor": 0.97
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.09323812651754765,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 44,
#                     "feature_weight": 0.08169952207141529,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 32,
#                     "feature_weight": 0.06467839113109065,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 13,
#                     "feature_weight": 0.052016565430834535,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 10,
#                     "feature_weight": 0.05148640570651179,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 9,
#                     "feature_weight": 0.02571147744757186,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 42,
#                     "feature_weight": 0.023494330325642125,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 10,
#                     "feature_weight": 0.01323758524458843,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 13,
#                     "feature_weight": 0.01270010429436888,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.010818958052815056,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.010113086954582563,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.008729147639901638,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.005691258159848672,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.004112374348361524,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.0037197854784388547,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0036308162217063016,
#                     "feature_ranges": null,
#                     "feature_rank": 16
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0034852486341215437,
#                     "feature_ranges": null,
#                     "feature_rank": 17
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0017564105935530478,
#                     "feature_ranges": null,
#                     "feature_rank": 18
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0008450124229482799,
#                     "feature_ranges": null,
#                     "feature_rank": 19
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0002970828696750368,
#                     "feature_ranges": null,
#                     "feature_rank": 20
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 3.0586680700167566e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 21
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.45712981731856434,
#             "local_prediction": 0.7062924642077191,
#             "features": [
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 44,
#                     "feature_weight": 0.05571868689699968,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.05140450116445657,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 13,
#                     "feature_weight": 0.04473234192018523,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 32,
#                     "feature_weight": 0.04065260664252824,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 42,
#                     "feature_weight": 0.03656703168277713,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.023652212431340133,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 10,
#                     "feature_weight": 0.021655757988618143,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 7
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9637479085331846,
#             "coverage": 0.0191,
#             "features": [
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 42,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 13,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 18.00",
#                     "feature_rank": 3
#                 }
#             ]
#         }
#     },
#     "99548": {
#         "forest_prediction": {
#             "not to refactor": 0.49,
#             "refactor": 0.51
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 52,
#                     "feature_weight": 0.07082448762246794,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 40,
#                     "feature_weight": 0.05632241360312517,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.05147922708284845,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 12,
#                     "feature_weight": 0.03081937901053193,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": 0.023806360696720406,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 30,
#                     "feature_weight": 0.022135762856746746,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.014684854764444527,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": 0.005221040363847994,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 10,
#                     "feature_weight": 0.004571488265823622,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.003843254451027073,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.003409350810319622,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0033611188150419833,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.0023739205365156464,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0012453822970158739,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 3.796730653958034e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5311779229377486,
#             "local_prediction": 0.5106677607425103,
#             "features": [
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.057348573452733385,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 40,
#                     "feature_weight": 0.052005294588750584,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 52,
#                     "feature_weight": 0.04974310118796689,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 30,
#                     "feature_weight": 0.03996490613989282,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 12,
#                     "feature_weight": 0.033475690931671534,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": 0.023822431718561424,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 6
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9657794676806084,
#             "coverage": 0.0018,
#             "features": [
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 30,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 2,
#                     "feature_weight": null,
#                     "feature_ranges": "methodParametersQty <= 2.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 8,
#                     "feature_weight": null,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 40,
#                     "feature_weight": null,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 12,
#                     "feature_weight": null,
#                     "feature_ranges": "methodAssignmentsQty > 1.00",
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 52,
#                     "feature_weight": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "methodWmc > 2.00",
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": null,
#                     "feature_ranges": "methodMaxNestedBlocks <= 1.00",
#                     "feature_rank": 10
#                 }
#             ]
#         }
#     },
#     "42623": {
#         "forest_prediction": {
#             "not to refactor": 0.1,
#             "refactor": 0.9
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 44,
#                     "feature_weight": 0.09943747537281462,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 11,
#                     "feature_weight": 0.09286582525476964,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 7,
#                     "feature_weight": 0.08418179569401699,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 35,
#                     "feature_weight": 0.07632619693015875,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 14,
#                     "feature_weight": 0.03626241164610176,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 13,
#                     "feature_weight": 0.02161496512452916,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 1,
#                     "feature_weight": 0.012627762278196857,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.009847588831970124,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 9,
#                     "feature_weight": 0.006618172243035008,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0063962228434345314,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.0063908325198334896,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.004174637288898191,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.002516242300954705,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0021351196095788848,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.001583891659593615,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0002566526803513638,
#                     "feature_ranges": null,
#                     "feature_rank": 16
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00016728699148169378,
#                     "feature_ranges": null,
#                     "feature_rank": 17
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 5.2923896729520325e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 18
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5498197315722846,
#             "local_prediction": 0.5863191887126831,
#             "features": [
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 11,
#                     "feature_weight": 0.06039424100238056,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 35,
#                     "feature_weight": 0.05365004772844699,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 44,
#                     "feature_weight": 0.04770058352549178,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 14,
#                     "feature_weight": 0.020584677127138136,
#                     "feature_ranges": "methodWmc > 5.00",
#                     "feature_rank": 4
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9601593625498008,
#             "coverage": 0.0205,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 7,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 18.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 11,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 13,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 1,
#                     "feature_weight": null,
#                     "feature_ranges": "methodParametersQty <= 1.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 9,
#                     "feature_weight": null,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "feature_rank": 5
#                 }
#             ]
#         }
#     },
#     "62913": {
#         "forest_prediction": {
#             "not to refactor": 0.51,
#             "refactor": 0.49
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.06741885767215788,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 41,
#                     "feature_weight": 0.05196349764413738,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 48,
#                     "feature_weight": 0.045098165489465596,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 13,
#                     "feature_weight": 0.03493254310843103,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 3,
#                     "feature_weight": 0.018377924610596556,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.013394203873891907,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 3,
#                     "feature_weight": 0.009010479897717283,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodParametersQty",
#                     "feature_value": 1,
#                     "feature_weight": 0.008345431115244654,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 9,
#                     "feature_weight": 0.007677328858526726,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 67,
#                     "feature_weight": 0.007246656651782406,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.00526291791656694,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.004284857368149526,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00314811430854426,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 1,
#                     "feature_weight": 0.0026164686228513467,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00237935679397022,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0015955898233920268,
#                     "feature_ranges": null,
#                     "feature_rank": 16
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0015016715745150091,
#                     "feature_ranges": null,
#                     "feature_rank": 17
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 3.261298519600668e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 18
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5326000693851246,
#             "local_prediction": 0.44820912767327425,
#             "features": [
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 48,
#                     "feature_weight": 0.052426124936734375,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 41,
#                     "feature_weight": 0.05135326209261229,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 17,
#                     "feature_weight": 0.0476362366060331,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 67,
#                     "feature_weight": 0.035786116265692156,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 4
#                 },
#                 {
# ...
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0008123089238036233,
#                     "feature_ranges": null,
#                     "feature_rank": 19
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00012968764880903774,
#                     "feature_ranges": null,
#                     "feature_rank": 20
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 6.957368098098687e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 21
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.40773193467482605,
#             "local_prediction": 0.7648461020806127,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 2,
#                     "feature_weight": 0.1532614319018238,
#                     "feature_ranges": "0.00 < bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 26,
#                     "feature_weight": 0.05181390879933978,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 50,
#                     "feature_weight": 0.05177623953935548,
#                     "feature_ranges": "methodLoc > 25.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 48,
#                     "feature_weight": 0.0473477696392469,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 22,
#                     "feature_weight": 0.03187596800884692,
#                     "feature_ranges": "methodAssignmentsQty > 5.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 12,
#                     "feature_weight": 0.019447786086975935,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.018750339704077624,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "feature_rank": 7
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9776876267748479,
#             "coverage": 0.0309,
#             "features": [
#                 {
#                     "feature_name": "bugFixCount",
#                     "feature_value": 2,
#                     "feature_weight": null,
#                     "feature_ranges": "bugFixCount <= 4.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 48,
#                     "feature_weight": null,
#                     "feature_ranges": "methodUniqueWordsQty > 26.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 8,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 3.00",
#                     "feature_rank": 3
#                 }
#             ]
#         }
#     },
#     "45343": {
#         "forest_prediction": {
#             "not to refactor": 0.15,
#             "refactor": 0.85
#         },
#         "shap": {
#             "features": [
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 23,
#                     "feature_weight": 0.14332161169559038,
#                     "feature_ranges": null,
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 24,
#                     "feature_weight": 0.06654824552903807,
#                     "feature_ranges": null,
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 22,
#                     "feature_weight": 0.06646625363235044,
#                     "feature_ranges": null,
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 25,
#                     "feature_weight": 0.047147771176400614,
#                     "feature_ranges": null,
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.04584139612623714,
#                     "feature_ranges": null,
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.04552689635125442,
#                     "feature_ranges": null,
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 12,
#                     "feature_weight": 0.02694551940038682,
#                     "feature_ranges": null,
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": 0.025504558557528836,
#                     "feature_ranges": null,
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodStringLiteralsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.02418472647899579,
#                     "feature_ranges": null,
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": 0.016866295446847875,
#                     "feature_ranges": null,
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodReturnQty",
#                     "feature_value": 2,
#                     "feature_weight": 0.015358447970906441,
#                     "feature_ranges": null,
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodNumbersQty",
#                     "feature_value": 1,
#                     "feature_weight": 0.009367451168481396,
#                     "feature_ranges": null,
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00783002436698856,
#                     "feature_ranges": null,
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodLoopQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0074799922330103606,
#                     "feature_ranges": null,
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodTryCatchQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0047115777457229354,
#                     "feature_ranges": null,
#                     "feature_rank": 15
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0012463355860067966,
#                     "feature_ranges": null,
#                     "feature_rank": 16
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.0008294048742944157,
#                     "feature_ranges": null,
#                     "feature_rank": 17
#                 },
#                 {
#                     "feature_name": "methodComparisonsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.00024286798679042497,
#                     "feature_ranges": null,
#                     "feature_rank": 18
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": 4.209015663368147e-05,
#                     "feature_ranges": null,
#                     "feature_rank": 19
#                 }
#             ]
#         },
#         "lime": {
#             "intercept": 0.5364074963320494,
#             "local_prediction": 0.4575001989895098,
#             "features": [
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 23,
#                     "feature_weight": 0.05202654323702824,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 25,
#                     "feature_weight": 0.04330142361121177,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 22,
#                     "feature_weight": 0.04084024246865992,
#                     "feature_ranges": "10.00 < methodLoc <= 25.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 24,
#                     "feature_weight": 0.02265258558082305,
#                     "feature_ranges": "13.00 < methodUniqueWordsQty <= 26.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": 0.022031555295782095,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 4,
#                     "feature_weight": 0.021424380823084958,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 6
#                 }
#             ]
#         },
#         "anchors": {
#             "precision": 0.9609375,
#             "coverage": 0.0037,
#             "features": [
#                 {
#                     "feature_name": "refactoringsInvolved",
#                     "feature_value": 25,
#                     "feature_weight": null,
#                     "feature_ranges": "refactoringsInvolved > 13.00",
#                     "feature_rank": 1
#                 },
#                 {
#                     "feature_name": "methodRfc",
#                     "feature_value": 23,
#                     "feature_weight": null,
#                     "feature_ranges": "methodRfc > 10.00",
#                     "feature_rank": 2
#                 },
#                 {
#                     "feature_name": "methodVariablesQty",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "methodVariablesQty > 3.00",
#                     "feature_rank": 3
#                 },
#                 {
#                     "feature_name": "methodAnonymousClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodAnonymousClassesQty <= 0.00",
#                     "feature_rank": 4
#                 },
#                 {
#                     "feature_name": "methodLoc",
#                     "feature_value": 22,
#                     "feature_weight": null,
#                     "feature_ranges": "methodLoc > 10.00",
#                     "feature_rank": 5
#                 },
#                 {
#                     "feature_name": "methodLambdasQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodLambdasQty <= 0.00",
#                     "feature_rank": 6
#                 },
#                 {
#                     "feature_name": "methodSubClassesQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodSubClassesQty <= 0.00",
#                     "feature_rank": 7
#                 },
#                 {
#                     "feature_name": "methodAssignmentsQty",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "methodAssignmentsQty > 1.00",
#                     "feature_rank": 8
#                 },
#                 {
#                     "feature_name": "methodUniqueWordsQty",
#                     "feature_value": 24,
#                     "feature_weight": null,
#                     "feature_ranges": "methodUniqueWordsQty > 13.00",
#                     "feature_rank": 9
#                 },
#                 {
#                     "feature_name": "methodWmc",
#                     "feature_value": 4,
#                     "feature_weight": null,
#                     "feature_ranges": "methodWmc > 2.00",
#                     "feature_rank": 10
#                 },
#                 {
#                     "feature_name": "methodMaxNestedBlocks",
#                     "feature_value": 1,
#                     "feature_weight": null,
#                     "feature_ranges": "methodMaxNestedBlocks > 0.00",
#                     "feature_rank": 11
#                 },
#                 {
#                     "feature_name": "methodReturnQty",
#                     "feature_value": 2,
#                     "feature_weight": null,
#                     "feature_ranges": "methodReturnQty > 0.00",
#                     "feature_rank": 12
#                 },
#                 {
#                     "feature_name": "methodParenthesizedExpsQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodParenthesizedExpsQty <= 0.00",
#                     "feature_rank": 13
#                 },
#                 {
#                     "feature_name": "methodMathOperationsQty",
#                     "feature_value": 0,
#                     "feature_weight": null,
#                     "feature_ranges": "methodMathOperationsQty <= 1.00",
#                     "feature_rank": 14
#                 },
#                 {
#                     "feature_name": "methodCbo",
#                     "feature_value": 12,
#                     "feature_weight": null,
#                     "feature_ranges": "methodCbo > 5.00",
#                     "feature_rank": 15
#                 }
#             ]
#         }
#     }
# }

# %%
def extract_feature_names(json_features):
    extracted_feature_names = []
    for f in json_features:
        extracted_feature_names.append(f['feature_name'])
    return extracted_feature_names

def get_info_by_feature_name(exp_f, feature_name):
    feature_obj = next(x for x in exp_f if x["feature_name"] == feature_name)
    return feature_obj['feature_value'], feature_obj['feature_weight'], feature_obj['feature_ranges'], feature_obj['feature_rank']

def compare_feature_weights(feature_value):
    # order = ['rank_anchors', 'rank_shap', 'rank_lime']
    # rank_order = []

    # for o in order:
    #     if o in feature_value
    #         rank_order.append(feature_value[o])
        
    if 'rank_shap' in feature_value and 'rank_lime' in feature_value and 'rank_anchors' in feature_value:
        return feature_value['rank_anchors'], feature_value['rank_shap'], feature_value['rank_lime']
    elif 'rank_shap' in feature_value and 'rank_lime' in feature_value:
        return feature_value['rank_shap'], feature_value['rank_lime']
    elif 'rank_shap' in feature_value and 'rank_anchors' in feature_value:
        return feature_value['rank_anchors'], feature_value['rank_shap']
    elif 'rank_lime' in feature_value and 'rank_anchors' in feature_value:
        return feature_value['rank_anchors'], feature_value['rank_lime']

def intersect_feature_explanations(feature_names, instance):
    shap_f = instance['shap']['features']
    lime_f = instance['lime']['features']
    anchors_f = instance['anchors']['features']

    shap_f_names = extract_feature_names(shap_f)
    lime_f_names = extract_feature_names(lime_f)
    anchors_f_names = extract_feature_names(anchors_f)

    intersec_3, intersec_shap_lime, intersec_shap_anchors, intersec_lime_anchors = ([] for i in range(4))
    compiled_intersec = dict()
    for f in feature_names:
        # for each configuration of intersection, gets feature name and explainers ranking
        # when finds feature in shap, lime and anchors
        if f in shap_f_names and f in lime_f_names and f in anchors_f_names:
            feature_summary = dict()
            feature_summary['feature_name'] = f
            # get info from explainers' features
            feature_value, _, anchors_ranges, anchors_rank = get_info_by_feature_name(anchors_f, f)
            _, shap_weight, _, shap_rank = get_info_by_feature_name(shap_f, f)
            _, lime_weight, lime_ranges, lime_rank = get_info_by_feature_name(lime_f, f)
            # feature value
            feature_summary['feature_value'] = feature_value
            # puts in dictionary
            feature_summary['rank_anchors'] = anchors_rank
            feature_summary['rank_shap'] = shap_rank
            feature_summary['rank_lime'] = lime_rank
            feature_summary['weight_shap'] = shap_weight
            feature_summary['weight_lime'] = lime_weight
            feature_summary['range_anchors'] = anchors_ranges
            feature_summary['range_lime'] = lime_ranges
            intersec_3.append(feature_summary)
        # when finds feature in shap and lime
        elif f in shap_f_names and f in lime_f_names:
            feature_summary = dict()
            feature_summary['feature_name'] = f
            # get info from explainers' features
            feature_value, shap_weight, _, shap_rank = get_info_by_feature_name(shap_f, f)
            _, lime_weight, lime_ranges, lime_rank = get_info_by_feature_name(lime_f, f)
            # feature value
            feature_summary['feature_value'] = feature_value
            # puts in dictionary
            feature_summary['rank_shap'] = shap_rank
            feature_summary['rank_lime'] = lime_rank
            feature_summary['weight_shap'] = shap_weight
            feature_summary['weight_lime'] = lime_weight
            feature_summary['range_lime'] = lime_ranges
            intersec_shap_lime.append(feature_summary)
        # when finds feature in shap and anchors
        elif f in shap_f_names and f in anchors_f_names:
            feature_summary = dict()
            feature_summary['feature_name'] = f
            # get info from explainers' features
            feature_value, _, anchors_ranges, anchors_rank = get_info_by_feature_name(anchors_f, f)
            _, shap_weight, _, shap_rank = get_info_by_feature_name(shap_f, f)
            # feature value
            feature_summary['feature_value'] = feature_value
            # puts in dictionary
            feature_summary['rank_anchors'] = anchors_rank
            feature_summary['rank_shap'] = shap_rank
            feature_summary['weight_shap'] = shap_weight
            feature_summary['range_anchors'] = anchors_ranges
            intersec_shap_anchors.append(feature_summary)
        # when finds feature in lime and anchors
        elif f in lime_f_names and f in anchors_f_names:
            feature_summary = dict()
            feature_summary['feature_name'] = f
            # get info from explainers' features
            feature_value, _, anchors_ranges, anchors_rank = get_info_by_feature_name(anchors_f, f)
            _, lime_weight, lime_ranges, lime_rank = get_info_by_feature_name(lime_f, f)
            # feature value
            feature_summary['feature_value'] = feature_value
            # puts in dictionary
            feature_summary['rank_anchors'] = anchors_rank
            feature_summary['rank_lime'] = lime_rank
            feature_summary['weight_lime'] = lime_weight
            feature_summary['range_anchors'] = anchors_ranges
            feature_summary['range_lime'] = lime_ranges
            intersec_lime_anchors.append(feature_summary)

    # order each list by importance (1st anchors, 2nd shap, 3rd lime)
    compiled_intersec['intersec_all'] = sorted(intersec_3, key=compare_feature_weights)
    compiled_intersec['intersec_shap_lime'] = sorted(intersec_shap_lime, key=compare_feature_weights)
    compiled_intersec['intersec_shap_anchors'] = sorted(intersec_shap_anchors, key=compare_feature_weights)
    compiled_intersec['intersec_lime_anchors'] = sorted(intersec_lime_anchors, key=compare_feature_weights)
    
    # print(json.dumps(compiled_intersec, indent=4))
    return compiled_intersec

# %%
# 1st: get interseccions between all the 3 explainers
# 2nd: get interseccions between 2 explainers
#      decision between explainers will have
#      priority -> 1 - anchors, 2 - shap, 3 - lime
def generate_top_n_features_v1(feature_names, json_out, n_f):
    final_explanations = dict()
    # run each instance
    for i in json_out:
        intersections = intersect_feature_explanations(feature_names, json_out[i])
        # 1st step of algorithm
        # get intersections between all explainers
        final_n_features = intersections['intersec_all'][0:n_f]
        # verify how many features misses to complete the x top features
        missing_features = n_f - len(final_n_features)
        
        if missing_features:
            # get x reamining features from each of intersections between 2 explainers
            i_shap_lime_f = intersections['intersec_shap_lime'][0:missing_features]
            i_shap_anchors_f = intersections['intersec_shap_anchors'][0:missing_features]
            i_lime_anchors_f = intersections['intersec_lime_anchors'][0:missing_features]
            # concat lists
            remaining_features = i_shap_lime_f+i_shap_anchors_f+i_lime_anchors_f
            # 2st step of algorithm
            # sort concatenated list
            sorted_remaining_features = sorted(remaining_features, key=compare_feature_weights)
            # concat features selected
            final_n_features = final_n_features + sorted_remaining_features[0:missing_features]

        instance_final_exp = dict()
        instance_final_exp['forest_prediction_to_refactor'] = json_out[i]['forest_prediction']['refactor']
        top_n_features_string = 'top_'+str(n_f)+'_features'
        instance_final_exp[top_n_features_string] = final_n_features
        
        final_explanations[i] = instance_final_exp

    #export explanations to json file
    file_name = 'top_'+str(n_f)+'_features_explanations.json'
    with open(file_name, "w") as outfile:
        json.dump(final_explanations, outfile)
        
    return final_explanations

final_explanations = generate_top_n_features_v1(feature_names, json_output_exp, 5)
print(json.dumps(final_explanations, indent=4))
# Out:
# {
#     "60621": {
#         "forest_prediction_to_refactor": 0.72,
#         "top_5_features": [
#             {
#                 "feature_name": "bugFixCount",
#                 "feature_value": 4,
#                 "rank_anchors": 1,
#                 "rank_shap": 1,
#                 "rank_lime": 1,
#                 "weight_shap": 0.08669926474690005,
#                 "weight_lime": 0.1481879078667768,
#                 "range_anchors": "bugFixCount <= 4.00",
#                 "range_lime": "0.00 < bugFixCount <= 4.00"
#             },
#             {
#                 "feature_name": "methodRfc",
#                 "feature_value": 32,
#                 "rank_anchors": 2,
#                 "rank_shap": 3,
#                 "rank_lime": 3,
#                 "weight_shap": 0.05268806497404086,
#                 "weight_lime": 0.05023540236417073,
#                 "range_anchors": "methodRfc > 10.00",
#                 "range_lime": "methodRfc > 10.00"
#             },
#             {
#                 "feature_name": "methodLoc",
#                 "feature_value": 77,
#                 "rank_shap": 2,
#                 "rank_lime": 4,
#                 "weight_shap": 0.058553218067354224,
#                 "weight_lime": 0.04518449733663578,
#                 "range_lime": "methodLoc > 25.00"
#             },
#             {
#                 "feature_name": "refactoringsInvolved",
#                 "feature_value": 4,
#                 "rank_anchors": 3,
#                 "rank_shap": 7,
#                 "weight_shap": 0.01671722985781716,
#                 "range_anchors": "refactoringsInvolved > 3.00"
#             },
#             {
#                 "feature_name": "methodVariablesQty",
#                 "feature_value": 8,
#                 "rank_shap": 4,
#                 "rank_lime": 6,
#                 "weight_shap": 0.04076783238029673,
#                 "weight_lime": 0.024416264069075943,
#                 "range_lime": "methodVariablesQty > 3.00"
#             }
#         ]
#     },
#     "63330": {
#         "forest_prediction_to_refactor": 0.81,
#         "top_5_features": [
#             {
#                 "feature_name": "bugFixCount",
#                 "feature_value": 3,
#                 "rank_anchors": 1,
#                 "rank_shap": 1,
#                 "rank_lime": 1,
#                 "weight_shap": 0.13021479262833538,
#                 "weight_lime": 0.14834476392584509,
#                 "range_anchors": "bugFixCount <= 4.00",
#                 "range_lime": "0.00 < bugFixCount <= 4.00"
#             },
#             {
#                 "feature_name": "methodRfc",
#                 "feature_value": 12,
#                 "rank_anchors": 2,
#                 "rank_shap": 4,
#                 "rank_lime": 4,
#                 "weight_shap": 0.04771967236981946,
#                 "weight_lime": 0.05116029399791379,
#                 "range_anchors": "methodRfc > 10.00",
#                 "range_lime": "methodRfc > 10.00"
#             },
#             {
#                 "feature_name": "methodLoc",
#                 "feature_value": 41,
#                 "rank_shap": 2,
#                 "rank_lime": 2,
#                 "weight_shap": 0.07097727154387841,
#                 "weight_lime": 0.05586231371387346,
#                 "range_lime": "methodLoc > 25.00"
#             },
#             {
#                 "feature_name": "methodUniqueWordsQty",
#                 "feature_value": 36,
#                 "rank_shap": 3,
#                 "rank_lime": 5,
#                 "weight_shap": 0.0627996083899755,
#                 "weight_lime": 0.04280026732909047,
#                 "range_lime": "methodUniqueWordsQty > 26.00"
#             },
#             {
#                 "feature_name": "methodWmc",
#                 "feature_value": 6,
#                 "rank_shap": 8,
#                 "rank_lime": 6,
#                 "weight_shap": 0.011428481808361405,
#                 "weight_lime": 0.020631890639955644,
#                 "range_lime": "methodWmc > 5.00"
#             }
#         ]
#     },
#     "84054": {
#         "forest_prediction_to_refactor": 0.97,
#         "top_5_features": [
#             {
#                 "feature_name": "methodLoc",
#                 "feature_value": 44,
#                 "rank_anchors": 2,
#                 "rank_shap": 2,
#                 "rank_lime": 2,
#                 "weight_shap": 0.08169952207141529,
#                 "weight_lime": 0.05070231825371531,
#                 "range_anchors": "methodLoc > 25.00",
#                 "range_lime": "methodLoc > 25.00"
#             },
#             {
#                 "feature_name": "refactoringsInvolved",
#                 "feature_value": 42,
#                 "rank_anchors": 3,
#                 "rank_shap": 7,
#                 "rank_lime": 4,
#                 "weight_shap": 0.023494330325642125,
#                 "weight_lime": 0.045562367169588,
#                 "range_anchors": "refactoringsInvolved > 13.00",
#                 "range_lime": "refactoringsInvolved > 13.00"
#             },
#             {
#                 "feature_name": "methodRfc",
#                 "feature_value": 17,
#                 "rank_shap": 1,
#                 "rank_lime": 3,
#                 "weight_shap": 0.09323812651754765,
#                 "weight_lime": 0.046475950233913745,
#                 "range_lime": "methodRfc > 10.00"
#             },
#             {
#                 "feature_name": "bugFixCount",
#                 "feature_value": 13,
#                 "rank_anchors": 1,
#                 "rank_shap": 9,
#                 "weight_shap": 0.01270010429436888,
#                 "range_anchors": "bugFixCount <= 18.00"
#             },
#             {
#                 "feature_name": "methodUniqueWordsQty",
#                 "feature_value": 32,
#                 "rank_shap": 3,
#                 "rank_lime": 5,
#                 "weight_shap": 0.06467839113109065,
#                 "weight_lime": 0.04462041581274514,
#                 "range_lime": "methodUniqueWordsQty > 26.00"
#             }
#         ]
#     },
#     "99548": {
#         "forest_prediction_to_refactor": 0.51,
#         "top_5_features": [
#             {
#                 "feature_name": "refactoringsInvolved",
#                 "feature_value": 30,
#                 "rank_anchors": 1,
#                 "rank_shap": 6,
#                 "rank_lime": 5,
#                 "weight_shap": 0.022135762856746746,
#                 "weight_lime": 0.046114312541648585,
#                 "range_anchors": "refactoringsInvolved > 13.00",
#                 "range_lime": "refactoringsInvolved > 13.00"
#             },
#             {
#                 "feature_name": "methodLoc",
#                 "feature_value": 40,
#                 "rank_anchors": 2,
#                 "rank_shap": 2,
#                 "rank_lime": 3,
#                 "weight_shap": 0.05632241360312517,
#                 "weight_lime": 0.052335297335246195,
#                 "range_anchors": "methodLoc > 25.00",
#                 "range_lime": "methodLoc > 25.00"
#             },
#             {
#                 "feature_name": "methodVariablesQty",
#                 "feature_value": 8,
#                 "rank_anchors": 3,
#                 "rank_shap": 5,
#                 "rank_lime": 6,
#                 "weight_shap": 0.023806360696720406,
#                 "weight_lime": 0.029260320738399046,
#                 "range_anchors": "methodVariablesQty > 3.00",
#                 "range_lime": "methodVariablesQty > 3.00"
#             },
#             {
#                 "feature_name": "methodSubClassesQty",
#                 "feature_value": 0,
#                 "rank_anchors": 8,
#                 "rank_shap": 15,
#                 "rank_lime": 1,
#                 "weight_shap": 3.796730653958034e-05,
#                 "weight_lime": 0.06766512468385802,
#                 "range_anchors": "methodSubClassesQty <= 0.00",
#                 "range_lime": "methodSubClassesQty <= 0.00"
#             },
#             {
#                 "feature_name": "methodUniqueWordsQty",
#                 "feature_value": 52,
#                 "rank_anchors": 9,
#                 "rank_shap": 1,
#                 "rank_lime": 4,
#                 "weight_shap": 0.07082448762246794,
#                 "weight_lime": 0.05061062090732389,
#                 "range_anchors": "methodUniqueWordsQty > 26.00",
#                 "range_lime": "methodUniqueWordsQty > 26.00"
#             }
#         ]
#     },
#     "42623": {
#         "forest_prediction_to_refactor": 0.9,
#         "top_5_features": [
#             {
#                 "feature_name": "methodRfc",
#                 "feature_value": 11,
#                 "rank_anchors": 2,
#                 "rank_shap": 2,
#                 "rank_lime": 2,
#                 "weight_shap": 0.09286582525476964,
#                 "weight_lime": 0.051072512459777474,
#                 "range_anchors": "methodRfc > 10.00",
#                 "range_lime": "methodRfc > 10.00"
#             },
#             {
#                 "feature_name": "methodLoc",
#                 "feature_value": 44,
#                 "rank_shap": 1,
#                 "rank_lime": 3,
#                 "weight_shap": 0.09943747537281462,
#                 "weight_lime": 0.044772270762823474,
#                 "range_lime": "methodLoc > 25.00"
#             },
#             {
#                 "feature_name": "refactoringsInvolved",
#                 "feature_value": 13,
#                 "rank_anchors": 1,
#                 "rank_shap": 6,
#                 "weight_shap": 0.02161496512452916,
#                 "range_anchors": "refactoringsInvolved > 3.00"
#             },
#             {
#                 "feature_name": "bugFixCount",
#                 "feature_value": 7,
#                 "rank_anchors": 3,
#                 "rank_shap": 3,
#                 "weight_shap": 0.08418179569401699,
#                 "range_anchors": "bugFixCount <= 18.00"
#             },
#             {
#                 "feature_name": "methodUniqueWordsQty",
#                 "feature_value": 35,
#                 "rank_shap": 4,
#                 "rank_lime": 1,
#                 "weight_shap": 0.07632619693015875,
#                 "weight_lime": 0.052042952543613984,
#                 "range_lime": "methodUniqueWordsQty > 26.00"
#             }
#         ]
#     },
#     "62913": {
#         "forest_prediction_to_refactor": 0.49,
#         "top_5_features": [
#             {
#                 "feature_name": "methodRfc",
#                 "feature_value": 17,
#                 "rank_shap": 1,
#                 "rank_lime": 1,
#                 "weight_shap": 0.06741885767215788,
#                 "weight_lime": 0.052601491306427876,
#                 "range_lime": "methodRfc > 10.00"
#             },
#             {
#                 "feature_name": "methodLoc",
#                 "feature_value": 41,
#                 "rank_shap": 2,
#                 "rank_lime": 3,
#                 "weight_shap": 0.05196349764413738,
#                 "weight_lime": 0.047038207539807565,
#                 "range_lime": "methodLoc > 25.00"
#             },
#             {
#                 "feature_name": "methodMaxNestedBlocks",
#                 "feature_value": 1,
#                 "rank_anchors": 2,
#                 "rank_shap": 12,
#                 "weight_shap": 0.004284857368149526,
#                 "range_anchors": "methodMaxNestedBlocks <= 1.00"
#             },
#             {
#                 "feature_name": "methodUniqueWordsQty",
#                 "feature_value": 48,
#                 "rank_shap": 3,
#                 "rank_lime": 2,
#                 "weight_shap": 0.045098165489465596,
#                 "weight_lime": 0.04989617660354985,
#                 "range_lime": "methodUniqueWordsQty > 26.00"
#             },
#             {
#                 "feature_name": "methodVariablesQty",
#                 "feature_value": 2,
#                 "rank_anchors": 3,
#                 "rank_shap": 6,
#                 "weight_shap": 0.013394203873891907,
#                 "range_anchors": "methodVariablesQty <= 3.00"
#             }
#         ]
#     },
#     "64822": {
#         "forest_prediction_to_refactor": 0.8,
#         "top_5_features": [
#             {
#                 "feature_name": "bugFixCount",
#                 "feature_value": 0,
#                 "rank_anchors": 1,
#                 "rank_shap": 1,
#                 "rank_lime": 1,
#                 "weight_shap": 0.09076048086079677,
#                 "weight_lime": 0.1073255743030638,
#                 "range_anchors": "bugFixCount <= 0.00",
#                 "range_lime": "bugFixCount <= 0.00"
#             },
#             {
#                 "feature_name": "methodAssignmentsQty",
#                 "feature_value": 14,
#                 "rank_anchors": 2,
#                 "rank_shap": 6,
#                 "rank_lime": 3,
#                 "weight_shap": 0.026642940955974984,
#                 "weight_lime": 0.03631196197480623,
#                 "range_anchors": "methodAssignmentsQty > 5.00",
#                 "range_lime": "methodAssignmentsQty > 5.00"
#             },
#             {
#                 "feature_name": "methodUniqueWordsQty",
#                 "feature_value": 52,
#                 "rank_shap": 2,
#                 "rank_lime": 2,
#                 "weight_shap": 0.0640324772455129,
#                 "weight_lime": 0.053258241723125946,
#                 "range_lime": "methodUniqueWordsQty > 26.00"
#             },
#             {
#                 "feature_name": "refactoringsInvolved",
#                 "feature_value": 8,
#                 "rank_anchors": 3,
#                 "rank_shap": 3,
#                 "weight_shap": 0.04499364746868278,
#                 "range_anchors": "refactoringsInvolved > 3.00"
#             },
#             {
#                 "feature_name": "methodVariablesQty",
#                 "feature_value": 14,
#                 "rank_shap": 4,
#                 "rank_lime": 5,
#                 "weight_shap": 0.0433356934729825,
#                 "weight_lime": 0.031363311595556935,
#                 "range_lime": "methodVariablesQty > 3.00"
#             }
#         ]
#     },
#     "833560": {
#         "forest_prediction_to_refactor": 0.84,
#         "top_5_features": [
#             {
#                 "feature_name": "refactoringsInvolved",
#                 "feature_value": 24,
#                 "rank_anchors": 1,
#                 "rank_shap": 6,
#                 "rank_lime": 4,
#                 "weight_shap": 0.015298521758291932,
#                 "weight_lime": 0.04612034012283267,
#                 "range_anchors": "refactoringsInvolved > 13.00",
#                 "range_lime": "refactoringsInvolved > 13.00"
#             },
#             {
#                 "feature_name": "methodLoc",
#                 "feature_value": 48,
#                 "rank_anchors": 2,
#                 "rank_shap": 2,
#                 "rank_lime": 3,
#                 "weight_shap": 0.0733552908106066,
#                 "weight_lime": 0.051101966954010085,
#                 "range_anchors": "methodLoc > 25.00",
#                 "range_lime": "methodLoc > 25.00"
#             },
#             {
#                 "feature_name": "methodRfc",
#                 "feature_value": 21,
#                 "rank_shap": 1,
#                 "rank_lime": 2,
#                 "weight_shap": 0.08153975998544344,
#                 "weight_lime": 0.054805862424718625,
#                 "range_lime": "methodRfc > 10.00"
#             },
#             {
#                 "feature_name": "methodAssignmentsQty",
#                 "feature_value": 19,
#                 "rank_shap": 3,
#                 "rank_lime": 5,
#                 "weight_shap": 0.05995468528973779,
#                 "weight_lime": 0.028897451370498498,
#                 "range_lime": "methodAssignmentsQty > 5.00"
#             },
#             {
#                 "feature_name": "bugFixCount",
#                 "feature_value": 13,
#                 "rank_anchors": 3,
#                 "rank_shap": 10,
#                 "weight_shap": 0.007199724792369284,
#                 "range_anchors": "bugFixCount <= 18.00"
#             }
#         ]
#     },
#     "45080": {
#         "forest_prediction_to_refactor": 0.98,
#         "top_5_features": [
#             {
#                 "feature_name": "bugFixCount",
#                 "feature_value": 2,
#                 "rank_anchors": 1,
#                 "rank_shap": 1,
#                 "rank_lime": 1,
#                 "weight_shap": 0.11294127770177226,
#                 "weight_lime": 0.14630460350461927,
#                 "range_anchors": "bugFixCount <= 4.00",
#                 "range_lime": "0.00 < bugFixCount <= 4.00"
#             },
#             {
#                 "feature_name": "methodVariablesQty",
#                 "feature_value": 12,
#                 "rank_anchors": 2,
#                 "rank_shap": 5,
#                 "rank_lime": 6,
#                 "weight_shap": 0.045786104773019316,
#                 "weight_lime": 0.024074037655989644,
#                 "range_anchors": "methodVariablesQty > 3.00",
#                 "range_lime": "methodVariablesQty > 3.00"
#             },
#             {
#                 "feature_name": "methodLoc",
#                 "feature_value": 50,
#                 "rank_shap": 2,
#                 "rank_lime": 2,
#                 "weight_shap": 0.07572264281278833,
#                 "weight_lime": 0.05596893916415951,
#                 "range_lime": "methodLoc > 25.00"
#             },
#             {
#                 "feature_name": "methodRfc",
#                 "feature_value": 26,
#                 "rank_shap": 3,
#                 "rank_lime": 3,
#                 "weight_shap": 0.07390051978880398,
#                 "weight_lime": 0.055499394545169466,
#                 "range_lime": "methodRfc > 10.00"
#             },
#             {
#                 "feature_name": "refactoringsInvolved",
#                 "feature_value": 8,
#                 "rank_anchors": 3,
#                 "rank_shap": 7,
#                 "weight_shap": 0.016973560058933967,
#                 "range_anchors": "refactoringsInvolved > 1.00"
#             }
#         ]
#     },
#     "45343": {
#         "forest_prediction_to_refactor": 0.85,
#         "top_5_features": [
#             {
#                 "feature_name": "refactoringsInvolved",
#                 "feature_value": 25,
#                 "rank_anchors": 1,
#                 "rank_shap": 4,
#                 "rank_lime": 2,
#                 "weight_shap": 0.047147771176400614,
#                 "weight_lime": 0.04970610778093022,
#                 "range_anchors": "refactoringsInvolved > 13.00",
#                 "range_lime": "refactoringsInvolved > 13.00"
#             },
#             {
#                 "feature_name": "methodRfc",
#                 "feature_value": 23,
#                 "rank_anchors": 2,
#                 "rank_shap": 1,
#                 "rank_lime": 3,
#                 "weight_shap": 0.14332161169559038,
#                 "weight_lime": 0.041277280392909454,
#                 "range_anchors": "methodRfc > 10.00",
#                 "range_lime": "methodRfc > 10.00"
#             },
#             {
#                 "feature_name": "methodVariablesQty",
#                 "feature_value": 4,
#                 "rank_anchors": 3,
#                 "rank_shap": 6,
#                 "rank_lime": 4,
#                 "weight_shap": 0.04552689635125442,
#                 "weight_lime": 0.03070432162417648,
#                 "range_anchors": "methodVariablesQty > 3.00",
#                 "range_lime": "methodVariablesQty > 3.00"
#             },
#             {
#                 "feature_name": "methodUniqueWordsQty",
#                 "feature_value": 24,
#                 "rank_anchors": 7,
#                 "rank_shap": 2,
#                 "rank_lime": 6,
#                 "weight_shap": 0.06654824552903807,
#                 "weight_lime": 0.021292368720183447,
#                 "range_anchors": "methodUniqueWordsQty > 13.00",
#                 "range_lime": "13.00 < methodUniqueWordsQty <= 26.00"
#             },
#             {
#                 "feature_name": "methodSubClassesQty",
#                 "feature_value": 0,
#                 "rank_anchors": 9,
#                 "rank_shap": 19,
#                 "rank_lime": 1,
#                 "weight_shap": 4.209015663368147e-05,
#                 "weight_lime": 0.10041492113605958,
#                 "range_anchors": "methodSubClassesQty <= 0.00",
#                 "range_lime": "methodSubClassesQty <= 0.00"
#             }
#         ]
#     }
# }
